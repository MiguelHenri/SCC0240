# %% [markdown]
# # Trabalho 2 de Banco de Dados - SCC0240

# %%
import pandas as pd

# %% [markdown]
# ## Imports e Testes
# Checando se tudo está funcionando

# %%
from ipywidgets import interact 
import ipywidgets as widgets
from sqlalchemy import create_engine

# %%
# %load_ext sql

engine = create_engine('postgresql://postgres:postgres@localhost/postgres')
# %sql postgresql://postgres:postgres@localhost/postgres
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting to 'postgresql://postgres:***@localhost/postgres'

# %% [markdown]
# Change displaylimit

# %%
# %config SqlMagic.displaylimit = 20
# %config SqlMagic.style = 'MARKDOWN'

# %%
# %%sql
# SELECT Current_database();
# Out:
# Running query in 'postgresql://postgres:***@localhost/postgres'
# 1 rows affected.
# | current_database |
# | :--------------: |
# |     postgres     |

# %% [markdown]
# ## 3. Criação e carga de tabelas

# %% [markdown]
# ### 1. Criação de tabelas do Airbnb

# %%
# %sql --file sql/3CriacaoAirbnb.sql
# Out:
# Running query in 'postgresql://postgres:***@localhost/postgres'
# ||
# ||

# %% [markdown]
# ### 2. Carga de tabelas do Airbnb

# %%
! psql -U postgres -c "\copy Reviews from /tmp/reviews.csv delimiter ',' CSV HEADER;"
! psql -U postgres -c "\copy Listings from /tmp/listings.csv delimiter ',' CSV HEADER;"
! psql -U postgres -c "\copy Calendar from /tmp/calendar.csv delimiter ',' CSV HEADER;"
# Out:
# COPY 402663
# COPY 36008
# COPY 13145595

# %%
# %%sql
# UPDATE Listings
# SET name_ = CONCAT(
#     SPLIT_PART(name_, '·', 1),
#     SPLIT_PART(name_, '·', 3),
#     SPLIT_PART(name_, '·', 4),
#     SPLIT_PART(name_, '·', 5)
# )
# Out:
# Running query in 'postgresql://postgres:***@localhost/postgres'
# 36008 rows affected.
# ||
# ||

# %%
# %%sql
# SELECT COUNT(id), name_, host_id
# FROM Listings
# GROUP BY name_, host_id
# ORDER BY count DESC
# Out:
# Running query in 'postgresql://postgres:***@localhost/postgres'
# 32519 rows affected.
# | count |                              name_                              |  host_id  |
# | :---: | :-------------------------------------------------------------: | :-------: |
# |   32  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    |  6000862  |
# |   27  |     Rental unit in Rio de Janeiro  1 bedroom  1 bed  1 bath     | 371026651 |
# |   22  | Serviced apartment in Barra da Tijuca  1 bedroom  1 bed  1 bath |  46664224 |
# |   21  |          Rental unit in Rio de Janeiro  5 beds  2 baths         |  47584281 |
# |   21  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    |  1982737  |
# |   20  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    |  30165706 |
# |   20  |  Serviced apartment in Rio de Janeiro  1 bedroom  1 bed  1 bath |  46664224 |
# |   19  |       Rental unit in Copacabana  1 bedroom  2 beds  1 bath      |  6000862  |
# |   17  |     Rental unit in Rio de Janeiro  1 bedroom  1 bed  1 bath     |  6000862  |
# |   16  |    Rental unit in Rio de Janeiro  2 bedrooms  2 beds  2 baths   | 341887136 |
# |   16  |          Rental unit in Rio de Janeiro  2 beds  2 baths         | 341887136 |
# |   14  |          Condo in Jacarepaguá  1 bedroom  1 bed  1 bath         | 331210726 |
# |   13  |           Rental unit in Rio de Janeiro  1 bed  1 bath          |  4307081  |
# |   13  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    |  74463624 |
# |   12  |    Rental unit in Rio de Janeiro  2 bedrooms  5 beds  2 baths   |  47584281 |
# |   12  |       Rental unit in Rio de Janeiro  1 bed  1 private bath      | 166827375 |
# |   11  |     Rental unit in Rio de Janeiro  1 bedroom  1 bed  1 bath     |  21365765 |
# |   11  |      Rental unit in Rio de Janeiro  7 beds  2 shared baths      | 481290301 |
# |   11  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    | 347487511 |
# |   11  |     Rental unit in Rio de Janeiro  1 bedroom  1 bed  1 bath     |  30165706 |
# Truncated to displaylimit of 20.

# %% [markdown]
# ### 3. Criação e carga de Tabelas mapeadas pelo MRel

# %%
# %%capture
# %sql --file sql/2CriacaoTabelasMRel.sql

# %sql --file sql/3CargaTabelasMRel.sql
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
#  * postgresql://postgres:***@localhost/trabbd
# 703796 rows affected.
# 6667756 rows affected.
# 156 rows affected.
# 36008 rows affected.
# 24462 rows affected.
# []

# %%
# %sql SELECT * FROM pg_catalog.pg_tables;
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 85 rows affected.
# [('pg_catalog', 'pg_statistic', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_type', 'postgres', None, True, False, False, False),
#  ('public', 'propriedades', 'postgres', None, True, False, False, False),
#  ('public', 'localizacoes', 'postgres', None, True, False, False, False),
#  ('public', 'usuarios', 'postgres', None, False, False, False, False),
#  ('public', 'mensagens', 'postgres', None, False, False, False, False),
#  ('public', 'locacao', 'postgres', None, False, False, False, False),
#  ('public', 'pontosinteresse', 'postgres', None, False, False, False, False),
#  ('public', 'fotos', 'postgres', None, False, False, False, False),
#  ('public', 'quartos', 'postgres', None, False, False, False, False),
#  ('public', 'comodidades', 'postgres', None, False, False, False, False),
#  ('public', 'contas', 'postgres', None, False, False, False, False),
#  ('public', 'datasdisponiveis', 'postgres', None, False, False, False, False),
#  ('public', 'regras', 'postgres', None, False, False, False, False),
#  ('pg_catalog', 'pg_foreign_server', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_authid', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_statistic_ext_data', 'postgres', None, True, False, False, False),
#  ('public', 'reviews', 'postgres', None, False, False, False, False),
#  ('public', 'listings', 'postgres', None, False, False, False, False),
#  ('public', 'calendar', 'postgres', None, False, False, False, False),
#  ('pg_catalog', 'pg_user_mapping', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_subscription', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_attribute', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_proc', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_class', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_attrdef', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_constraint', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_inherits', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_index', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_operator', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_opfamily', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_opclass', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_am', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_amop', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_amproc', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_language', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_largeobject_metadata', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_aggregate', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_largeobject', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_statistic_ext', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_rewrite', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_trigger', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_event_trigger', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_description', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_cast', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_enum', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_namespace', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_conversion', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_depend', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_database', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_db_role_setting', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_tablespace', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_pltemplate', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_auth_members', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_shdepend', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_shdescription', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_ts_config', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_ts_config_map', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_ts_dict', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_ts_parser', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_ts_template', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_extension', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_foreign_data_wrapper', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_foreign_table', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_policy', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_replication_origin', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_default_acl', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_init_privs', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_seclabel', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_shseclabel', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_collation', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_partitioned_table', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_range', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_transform', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_sequence', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_publication', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_publication_rel', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_subscription_rel', 'postgres', None, True, False, False, False),
#  ('information_schema', 'sql_packages', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_features', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_implementation_info', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_parts', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_languages', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_sizing', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_sizing_profiles', 'postgres', None, False, False, False, False)]

# %% [markdown]
# ## 4. Consultas

# %% [markdown]
# ### Exercício 6

# %%
# %sql SELECT * FROM Propriedades ORDER BY RANDOM() LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 10 rows affected.
# [(761040114387357006, 'Rental unit in Rio de Janeiro · ★5.0 · 1 bedroom · 2 beds · 1 bath', None, 51, 40877607, None, None, 614.0, None, 3, None, None, None, None, None),
#  (14314355, 'Rental unit in Rio de Janeiro · 2 bedrooms · 1 bed · 2 baths', None, 119, 83748330, None, None, 964.0, None, 7, None, None, None, None, None),
#  (38996111, 'Rental unit in Jacarepaguá · ★4.80 · 1 bedroom · 3 beds · 1 bath', None, 38, 298803263, None, None, 473.0, None, 3, None, None, None, None, None),
#  (12985673, 'Rental unit in Rio de Janeiro · ★4.90 · 2 bedrooms · 2 beds · 2 baths', None, 99, 50607901, None, None, 876.0, None, 2, None, None, None, None, None),
#  (775456276016614003, 'Hotel in Rio de Janeiro · 1 bedroom · 1 bed · 1 private bath', None, 119, 128990735, None, None, 857.0, None, 7, None, None, None, None, None),
#  (610164796704160473, 'Rental unit in Copacabana · ★4.87 · 1 bedroom · 1 bed · 1 private bath', None, 41, 434348285, None, None, 657.0, None, 4, None, None, None, None, None),
#  (32374354, 'Rental unit in Botafogo · ★4.67 · Studio · 5 beds · 1 bath', None, 24, 101282776, None, None, 121.0, None, 1, None, None, None, None, None),
#  (2769769, 'Rental unit in Rio · ★4.75 · 1 bedroom · 1 bed · 1 private bath', None, 41, 14163574, None, None, 280.0, None, 3, None, None, None, None, None),
#  (31689030, 'Rental unit in Barra da Tijuca · 1 bedroom · 3 beds · 1 bath', None, 99, 158386090, None, None, 600.0, None, 1, None, None, None, None, None),
#  (6844257, 'Home in Rio de Janeiro · ★5.0 · 1 bedroom · 2 beds · 1 bath', None, 72, 10491771, None, None, 274.0, None, 5, None, None, None, None, None)]

# %%
sql_query = """
SELECT
    CASE
        WHEN minnoites = 1 THEN '1'
        WHEN minnoites = 2 THEN '2'
        WHEN minnoites = 3 THEN '3'
        WHEN minnoites = 4 THEN '4'
        WHEN minnoites >= 5 THEN '5 ou mais'
    END AS MinNoites,
    COUNT(*) AS NumPropriedades
FROM
    Propriedades
GROUP BY
    CASE
        WHEN minnoites = 1 THEN '1'
        WHEN minnoites = 2 THEN '2'
        WHEN minnoites = 3 THEN '3'
        WHEN minnoites = 4 THEN '4'
        WHEN minnoites >= 5 THEN '5 ou mais'
    END
ORDER BY
    MinNoites;
"""

# %sql $sql_query
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 5 rows affected.
# [('1', 9243), ('2', 10443), ('3', 7858), ('4', 2883), ('5 ou mais', 5581)]

# %%
# %sql SELECT COUNT(*) AS NumeroLocalizacoes FROM Localizacoes;
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 1 rows affected.
# [(156,)]

# %% [markdown]
# ### Exercício 7

# %%
# %sql --file sql/ex7.sql
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
# 12 rows affected.
# [(1.0, 1329.1753055440604),
#  (2.0, 1323.7826720229286),
#  (3.0, 1242.4417729409627),
#  (4.0, 1290.4259413334337),
#  (5.0, 1286.8790061012612),
#  (6.0, 1298.3419265975792),
#  (7.0, 1354.2343028632836),
#  (8.0, 1357.2291659674443),
#  (9.0, 1378.3846521373125),
#  (10.0, 1441.7579053498966),
#  (11.0, 1434.3198859215672),
#  (12.0, 1404.391295106963)]

# %% [markdown]
# ### Exercício 8

# %%
sql_query = """
SELECT
    U.ID,
    U.Nome, 
    L.Cidade,
    COUNT(P.ID) AS QuantidadeDeImoveis
FROM 
    Usuarios U
JOIN 
    Localizacoes L ON U.IDLocalizacao = L.ID
JOIN 
    Propriedades P ON U.ID = P.IDAnfitriao
GROUP BY 
    U.ID, U.Nome, L.Cidade
HAVING 
    COUNT(P.ID) >= 3
ORDER BY 
    QuantidadeDeImoveis DESC;
"""

# sem index
# %sql EXPLAIN ANALYZE $sql_query
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 20 rows affected.
# [('Sort  (cost=4677.55..4695.86 rows=7327 width=35) (actual time=242.149..243.471 rows=2743 loops=1)',),
#  ('  Sort Key: (count(p.id)) DESC',),
#  ('  Sort Method: quicksort  Memory: 313kB',),
#  ('  ->  HashAggregate  (cost=3932.44..4207.19 rows=7327 width=35) (actual time=234.848..240.387 rows=2743 loops=1)',),
#  ('        Group Key: u.id, u.nome, l.cidade',),
#  ('        Filter: (count(p.id) >= 3)',),
#  ('        Rows Removed by Filter: 19237',),
#  ('        ->  Hash Join  (cost=804.86..3192.26 rows=59214 width=35) (actual time=51.574..157.869 rows=68414 loops=1)',),
#  ('              Hash Cond: (p.idanfitriao = u.id)',),
#  ('              ->  Seq Scan on propriedades p  (cost=0.00..985.08 rows=36008 width=12) (actual time=0.032..23.789 rows=36008 loops=1)',),
#  ('              ->  Hash  (cost=499.09..499.09 rows=24462 width=27) (actual time=51.525..51.539 rows=24462 loops=1)',),
#  ('                    Buckets: 32768  Batches: 1  Memory Usage: 1673kB',),
#  ('                    ->  Hash Join  (cost=5.51..499.09 rows=24462 width=27) (actual time=0.214..35.021 rows=24462 loops=1)',),
#  ('                          Hash Cond: (u.idlocalizacao = l.id)',),
#  ('                          ->  Seq Scan on usuarios u  (cost=0.00..427.62 rows=24462 width=16) (actual time=0.013..11.249 rows=24462 loops=1)',),
#  ('                          ->  Hash  (cost=3.56..3.56 rows=156 width=19) (actual time=0.192..0.197 rows=156 loops=1)',),
#  ('                                Buckets: 1024  Batches: 1  Memory Usage: 16kB',),
#  ('                                ->  Seq Scan on localizacoes l  (cost=0.00..3.56 rows=156 width=19) (actual time=0.015..0.098 rows=156 loops=1)',),
#  ('Planning Time: 0.361 ms',),
#  ('Execution Time: 244.775 ms',)]

# %%
# com index
# %sql DROP INDEX IF EXISTS indexAnfitriao;
# %sql CREATE INDEX indexAnfitriao ON Propriedades (IDAnfitriao);
# %sql EXPLAIN ANALYZE $sql_query
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
#  * postgresql://postgres:***@localhost/trabbd
# Done.
#  * postgresql://postgres:***@localhost/trabbd
# 20 rows affected.
# [('Sort  (cost=4677.55..4695.86 rows=7327 width=35) (actual time=163.256..164.544 rows=2743 loops=1)',),
#  ('  Sort Key: (count(p.id)) DESC',),
#  ('  Sort Method: quicksort  Memory: 313kB',),
#  ('  ->  HashAggregate  (cost=3932.44..4207.19 rows=7327 width=35) (actual time=156.782..161.642 rows=2743 loops=1)',),
#  ('        Group Key: u.id, u.nome, l.cidade',),
#  ('        Filter: (count(p.id) >= 3)',),
#  ('        Rows Removed by Filter: 19237',),
#  ('        ->  Hash Join  (cost=804.86..3192.26 rows=59214 width=35) (actual time=38.531..108.793 rows=68414 loops=1)',),
#  ('              Hash Cond: (p.idanfitriao = u.id)',),
#  ('              ->  Seq Scan on propriedades p  (cost=0.00..985.08 rows=36008 width=12) (actual time=0.017..15.544 rows=36008 loops=1)',),
#  ('              ->  Hash  (cost=499.09..499.09 rows=24462 width=27) (actual time=38.341..38.346 rows=24462 loops=1)',),
#  ('                    Buckets: 32768  Batches: 1  Memory Usage: 1673kB',),
#  ('                    ->  Hash Join  (cost=5.51..499.09 rows=24462 width=27) (actual time=0.145..26.329 rows=24462 loops=1)',),
#  ('                          Hash Cond: (u.idlocalizacao = l.id)',),
#  ('                          ->  Seq Scan on usuarios u  (cost=0.00..427.62 rows=24462 width=16) (actual time=0.012..8.512 rows=24462 loops=1)',),
#  ('                          ->  Hash  (cost=3.56..3.56 rows=156 width=19) (actual time=0.129..0.130 rows=156 loops=1)',),
#  ('                                Buckets: 1024  Batches: 1  Memory Usage: 16kB',),
#  ('                                ->  Seq Scan on localizacoes l  (cost=0.00..3.56 rows=156 width=19) (actual time=0.012..0.067 rows=156 loops=1)',),
#  ('Planning Time: 3.504 ms',),
#  ('Execution Time: 166.159 ms',)]

# %%
# %sql $sql_query
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 2743 rows affected.
# [(91654021, 'Daniel', 'Rio de Janeiro', 2198),
#  (371026651, 'Pineapples', 'Rio de Janeiro', 1664),
#  (1982737, 'Estadia', 'Rio de Janeiro', 1420),
#  (341887136, 'Tabas', 'Rio de Janeiro', 1305),
#  (6000862, 'Omar Do Rio', 'Rio de Janeiro', 1295),
#  (30165706, 'Yes Temporada', 'Rio de Janeiro', 1232),
#  (47584281, 'Renato', 'Rio de Janeiro', 1136),
#  (12909867, 'Giovanni', 'Rio de Janeiro', 690),
#  (14315601, 'Aroldo', 'Rio de Janeiro', 680),
#  (310319158, 'Suellen', 'Rio de Janeiro', 560),
#  (160833906, 'RioHost', 'Rio de Janeiro', 533),
#  (392083762, 'Oka', 'Rio de Janeiro', 473),
#  (8975746, 'Line Rio', 'Rio de Janeiro', 450),
#  (319227148, 'Anfitrião Prime', 'Rio de Janeiro', 420),
#  (22805631, 'Latin Exclusive', 'Rio de Janeiro', 414),
#  (2513825, 'Further', 'Rio de Janeiro', 400),
#  (60298129, 'Danide', 'Rio de Janeiro', 400),
#  (4005407, 'Erika', 'Rio de Janeiro', 385),
#  (49207110, 'Anfitriao Gente Boa', 'Rio de Janeiro', 343),
#  (74463624, 'Mozart', 'Rio de Janeiro', 320),
#  (27229964, 'Beatriz', 'Rio de Janeiro', 315),
#  (22713969, 'Maria', 'Rio de Janeiro', 304),
#  (4255118, 'Ricardo', 'Rio de Janeiro', 294),
#  (15533343, 'Yuri', 'Rio de Janeiro', 264),
#  (8303861, 'Carlos Eduardo', 'Rio de Janeiro', 261),
#  (153721, 'Shushma', 'Rio de Janeiro', 256),
#  (13580277, 'Marcio', 'Rio de Janeiro', 255),
#  (70646886, 'LuxoBrasil', 'Rio de Janeiro', 252),
#  (4307081, 'Nereu A', 'Rio de Janeiro', 250),
#  (1422607, 'Leo&Archanjo', 'Rio de Janeiro', 235),
#  (2919803, 'Felipe', 'Rio de Janeiro', 230),
#  (9270905, 'Carlos', 'Rio de Janeiro', 222),
#  (257601767, 'Raquel Grama', 'Rio de Janeiro', 204),
#  (92284964, 'BestStay', 'Rio de Janeiro', 200),
#  (14314998, 'Rio Unique', 'Rio de Janeiro', 200),
#  (10406037, 'Rio Houses', 'Rio de Janeiro', 196),
#  (532498, 'Luis', 'Rio de Janeiro', 188),
#  (468723322, 'Villas In Brazil', 'Rio de Janeiro', 182),
#  (74652696, 'Andreia', 'Rio de Janeiro', 182),
#  (36744189, 'Monica', 'Rio de Janeiro', 172),
#  (13323106, 'Allan', 'Rio de Janeiro', 170),
#  (149407, 'Ricardo', 'Rio de Janeiro', 168),
#  (347487511, 'Rodrigo', 'Rio de Janeiro', 165),
#  (21218739, 'Pedro', 'Rio de Janeiro', 156),
#  (459544, 'Temporada', 'Rio de Janeiro', 155),
#  (473492239, 'Mauricio', 'Rio de Janeiro', 155),
#  (43898034, 'Giovani', 'Rio de Janeiro', 152),
#  (26945147, 'Smartbnb', 'Rio de Janeiro', 152),
#  (71645815, 'Adilson', 'Rio de Janeiro', 150),
#  (137007102, 'FGibran', 'Rio de Janeiro', 144),
#  (325713553, 'Filipe', 'Rio de Janeiro', 144),
#  (21365765, 'Unhotel', 'Rio de Janeiro', 140),
#  (146347544, 'Frédéric', 'Rio de Janeiro', 135),
#  (102761308, 'Caio', 'Rio de Janeiro', 132),
#  (318672692, 'Rafael', 'Rio de Janeiro', 130),
#  (823800, 'Rafaella', 'Rio de Janeiro', 126),
#  (113997985, 'HomeRio', 'Rio de Janeiro', 125),
#  (321818201, 'Maria Luisa', 'Rio de Janeiro', 125),
#  (292590334, 'Belsito Apartments', 'Rio de Janeiro', 123),
#  (108643221, 'Celso Teixeira', 'Rio de Janeiro', 120),
#  (231818330, 'Matheus', 'Rio de Janeiro', 119),
#  (46664224, 'Rafael', 'Rio de Janeiro', 114),
#  (378545175, 'Jorge Luiz', 'Rio de Janeiro', 112),
#  (57671630, 'Leander', 'Rio de Janeiro', 110),
#  (352008051, 'Marcolini', 'Rio de Janeiro', 108),
#  (13359269, 'Antonio', 'Rio de Janeiro', 105),
#  (10541644, 'Virginia', 'Rio de Janeiro', 100),
#  (30721359, 'I Live Global', 'Rio de Janeiro', 100),
#  (272976656, 'Marcus Vinícius', 'Rio de Janeiro', 96),
#  (408071697, 'Gabriela', 'Rio de Janeiro', 95),
#  (2438594, 'WhereInRio', 'Rio de Janeiro', 92),
#  (23369184, 'Juliana - Temporada Curta', 'Rio de Janeiro', 90),
#  (446405145, 'Joel', 'Rio de Janeiro', 90),
#  (363700178, 'Ceres', 'Rio de Janeiro', 90),
#  (148937129, 'Alessandra', 'Rio de Janeiro', 87),
#  (21931975, 'Rio Temporada', 'Rio de Janeiro', 85),
#  (5737780, 'Fabi', 'Rio de Janeiro', 85),
#  (80329631, 'Neide', 'Rio de Janeiro', 84),
#  (10423223, 'Carlos Rio Reservas', 'Rio de Janeiro', 84),
#  (15275005, 'Jonas', 'Rio de Janeiro', 84),
#  (249003418, 'Best', 'Rio de Janeiro', 81),
#  (365760452, 'Rosi', 'Rio de Janeiro', 80),
#  (84751001, 'Eveline', 'Rio de Janeiro', 80),
#  (351259985, 'Carolina', 'Rio de Janeiro', 78),
#  (164822022, 'Temporada', 'Rio de Janeiro', 78),
#  (4420701, 'Gustavo', 'Rio de Janeiro', 77),
#  (20370177, 'Sylvie', 'Rio de Janeiro', 76),
#  (463844986, 'Lobie', 'Rio de Janeiro', 76),
#  (366913236, 'Daniel', 'Rio de Janeiro', 75),
#  (172345271, 'Monica', 'Rio de Janeiro', 75),
#  (15900036, 'Israel Fagundes', 'Rio de Janeiro', 72),
#  (83831825, 'Mi Casa Su Casa', 'Rio de Janeiro', 72),
#  (397106841, 'Jump In', 'Rio de Janeiro', 70),
#  (31226043, 'Alan', 'Rio de Janeiro', 68),
#  (271367467, 'Anna', 'Rio de Janeiro', 66),
#  (4376064, 'Anfitriões', 'Rio de Janeiro', 66),
#  (6786750, 'Matteo', 'Rio de Janeiro', 64),
#  (5615480, 'Andrea', 'Rio de Janeiro', 64),
#  (463573876, 'Aran', 'Rio de Janeiro', 64),
#  (229244053, 'Leda', 'Rio de Janeiro', 63),
#  (13949537, 'Alexander', 'Rio de Janeiro', 63),
#  (348293564, 'Juliana', 'Rio de Janeiro', 60),
#  (10507162, 'Mauricio', 'Rio de Janeiro', 60),
#  (11782291, 'Lucas', 'Rio de Janeiro', 60),
#  (62031792, 'Rodrigo', 'Rio de Janeiro', 60),
#  (167997008, 'Monica', 'Rio de Janeiro', 60),
#  (27994357, 'Henrique', 'Rio de Janeiro', 60),
#  (401229484, 'Manuella', 'Rio de Janeiro', 60),
#  (39135642, 'Juliana', 'Rio de Janeiro', 60),
#  (894049, 'Janara', 'Rio de Janeiro', 60),
#  (167472593, 'Rio Stay Residence', 'Rio de Janeiro', 60),
#  (238544772, 'Cesar', 'Rio de Janeiro', 57),
#  (11070008, 'BlissRio', 'Rio de Janeiro', 55),
#  (14095160, 'Claudia', 'Rio de Janeiro', 54),
#  (36258642, 'Patrick', 'Rio de Janeiro', 52),
#  (55128713, 'Normando', 'Rio de Janeiro', 52),
#  (8669485, 'Adriano', 'Rio de Janeiro', 52),
#  (25067261, 'Emma', 'Rio de Janeiro', 51),
#  (10486509, 'Arno & Igor', 'Rio de Janeiro', 50),
#  (62525920, 'Adriana', 'Rio de Janeiro', 50),
#  (15925374, 'Luiz Renato', 'Rio de Janeiro', 48),
#  (9226189, 'Débora', 'Rio de Janeiro', 48),
#  (4438776, 'Elisabete', 'Rio de Janeiro', 48),
#  (499353982, 'Comercial', 'Rio de Janeiro', 48),
#  (211001893, 'Fabio', 'Rio de Janeiro', 48),
#  (526672837, 'Minha Casa De Temporada', 'Rio de Janeiro', 48),
#  (25130130, 'Fabio', 'Rio de Janeiro', 48),
#  (90268480, 'Marcos', 'Rio de Janeiro', 48),
#  (13411812, 'Fernando', 'Rio de Janeiro', 48),
#  (3665789, 'Beta Gatti', 'Rio de Janeiro', 48),
#  (16064460, 'Rômulo', 'Rio de Janeiro', 46),
#  (148198271, 'Verônica', 'Rio de Janeiro', 45),
#  (232555342, 'Regina', 'Rio de Janeiro', 45),
#  (454830327, 'Clara', 'Rio de Janeiro', 45),
#  (8364280, 'Jan', 'Rio de Janeiro', 45),
#  (192303063, 'Sivaldo', 'Rio de Janeiro', 45),
#  (77709888, 'Vanessa', 'Rio de Janeiro', 45),
#  (315740743, 'Maicon', 'Rio de Janeiro', 44),
#  (330224882, 'Josue', 'Rio de Janeiro', 44),
#  (238604267, 'Claudia', 'Rio de Janeiro', 44),
#  (8782308, 'Julia Zany', 'Rio de Janeiro', 44),
#  (1577817, 'Olivier', 'Rio de Janeiro', 42),
#  (35739862, 'Rodrigo', 'Rio de Janeiro', 42),
#  (3018529, 'Marcia', 'Rio de Janeiro', 42),
#  (83354976, 'Adriano', 'Rio de Janeiro', 40),
#  (490978942, 'Hans', 'Rio de Janeiro', 40),
#  (277358509, 'Flat Residence', 'Rio de Janeiro', 40),
#  (11504031, 'Valdene', 'Rio de Janeiro', 40),
#  (235177717, 'Claudio', 'Rio de Janeiro', 40),
#  (79151243, 'Breno', 'Rio de Janeiro', 40),
#  (2312911, 'Elena E Sergio', 'Rio de Janeiro', 39),
#  (83729062, 'William', 'Rio de Janeiro', 39),
#  (216622191, 'Marilene', 'Rio de Janeiro', 39),
#  (13392098, 'Vinicio', 'Rio de Janeiro', 39),
#  (10607843, 'Rio Hosting', 'Rio de Janeiro', 39),
#  (601323, 'Laurent', 'Rio de Janeiro', 36),
#  (492291708, 'Jacqueline', 'Rio de Janeiro', 36),
#  (11323527, 'David', 'Rio de Janeiro', 36),
#  (74338742, 'Atel', 'Rio de Janeiro', 36),
#  (511384819, 'João Ricardo', 'Rio de Janeiro', 36),
#  (272752257, 'Felipe', 'Rio de Janeiro', 36),
#  (115138742, 'Karina', 'Rio de Janeiro', 36),
#  (56259668, 'Sabrina Franklin', 'Rio de Janeiro', 36),
#  (112504243, 'Sonia', 'Rio de Janeiro', 36),
#  (166827375, 'More Só', 'Rio de Janeiro', 36),
#  (66039372, 'Vitor & Carlos', 'Rio de Janeiro', 36),
#  (503285061, 'Pedro', 'Rio de Janeiro', 36),
#  (229472947, 'Valeska', 'Rio de Janeiro', 36),
#  (34459302, 'Gisele', 'Rio de Janeiro', 35),
#  (10823485, 'Vania', 'Rio de Janeiro', 35),
#  (67255068, 'Home', 'Rio de Janeiro', 35),
#  (302209040, 'Vinicius', 'Rio de Janeiro', 35),
#  (13272749, 'Sonia', 'Rio de Janeiro', 35),
#  (309591724, 'Renato', 'Rio de Janeiro', 34),
#  (401842074, 'Nayana', 'Rio de Janeiro', 34),
#  (489381613, 'Marcos Rodrigo', 'Rio de Janeiro', 33),
#  (534675, 'Junior', 'Rio de Janeiro', 33),
#  (44729495, 'Juliana', 'Rio de Janeiro', 32),
#  (513685, 'Carlos', 'Rio de Janeiro', 32),
#  (429775424, 'Helô', 'Rio de Janeiro', 32),
#  (26414324, 'Alire Lima', 'Rio de Janeiro', 32),
#  (8477603, 'Pamela', 'Rio de Janeiro', 32),
#  (352599409, 'Best In Rio Stay Convention Suites', 'Rio de Janeiro', 30),
#  (15013867, 'Fernanda', 'Rio de Janeiro', 30),
#  (51227019, 'Pedro', 'Rio de Janeiro', 30),
#  (36289458, 'Maria', 'Rio de Janeiro', 30),
#  (70933, 'Goitaca', 'Rio de Janeiro', 30),
#  (29475411, 'Bruno & Ricardo', 'Rio de Janeiro', 30),
#  (10640170, 'Ana', 'Rio de Janeiro', 30),
#  (4581272, 'Diogo Rio Habitat', 'Rio de Janeiro', 30),
#  (13664216, 'Maria Lucia', 'Rio de Janeiro', 30),
#  (12938211, 'Luxury Worldwide', 'Rio de Janeiro', 30),
#  (224799115, 'Isabela', 'Rio de Janeiro', 30),
#  (48024, 'Gustavo', 'Rio de Janeiro', 28),
#  (67587712, 'Gabriel', 'Rio de Janeiro', 28),
#  (249164320, 'Carlos Arthur', 'Rio de Janeiro', 28),
#  (11386725, 'Carolina', 'Rio de Janeiro', 28),
#  (39817386, 'Reserve', 'Rio de Janeiro', 28),
#  (156636821, 'Thaissa', 'Rio de Janeiro', 28),
#  (27709253, 'Eliane', 'Rio de Janeiro', 28),
#  (521593918, 'Oka', 'Rio de Janeiro', 28),
#  (12902528, 'Lilien', 'Rio de Janeiro', 28),
#  (320261036, 'Jefferson', 'Rio de Janeiro', 28),
#  (5838889, 'Marie', 'Rio de Janeiro', 28),
#  (4284876, 'Silvia', 'Rio de Janeiro', 27),
#  (13753183, 'Raíssa', 'Rio de Janeiro', 27),
#  (1537641, 'Gilles', 'Rio de Janeiro', 27),
#  (27909203, 'Sandra', 'Rio de Janeiro', 27),
#  (483447030, 'Ruy', 'Rio de Janeiro', 27),
#  (14015723, 'Geraldo & Simone', 'Rio de Janeiro', 27),
#  (46226066, 'Alvar Mario', 'Rio de Janeiro', 27),
#  (500936420, 'Fernanda', 'Rio de Janeiro', 27),
#  (174004959, 'Jorge', 'Rio de Janeiro', 26),
#  (98289727, 'Mm Aluguel Por Temporada', 'Rio de Janeiro', 26),
#  (288667254, 'Cintia', 'Rio de Janeiro', 25),
#  (9739433, 'Vivian', 'Rio de Janeiro', 24),
#  (413577, 'Bernardo', 'Rio de Janeiro', 24),
#  (4622315, 'Rafael', 'Rio de Janeiro', 24),
#  (511069283, 'Copa', 'Rio de Janeiro', 24),
#  (490731280, 'Gabriel', 'Rio de Janeiro', 24),
#  (423192660, 'Erica', 'Rio de Janeiro', 24),
#  (63954449, 'Jorge', 'Rio de Janeiro', 24),
#  (26748682, 'Rose', 'Rio de Janeiro', 24),
#  (523903815, 'Reinaldo', 'Rio de Janeiro', 24),
#  (506564579, 'Simone', 'Rio de Janeiro', 24),
#  (4106244, 'Guilherme', 'Rio de Janeiro', 24),
#  (22240461, 'Tatiana', 'Rio de Janeiro', 24),
#  (378854391, 'Stacy E Bueno', 'Rio de Janeiro', 24),
#  (30975221, 'Rio Guests', 'Rio de Janeiro', 24),
#  (13952932, 'Fabiana', 'Rio de Janeiro', 24),
#  (85897939, 'Flavia Prista', 'Rio de Janeiro', 24),
#  (78713589, 'Augusto', 'Rio de Janeiro', 24),
#  (431676014, 'Sabrina', 'Rio de Janeiro', 24),
#  (15175491, 'Pricila', 'Rio de Janeiro', 24),
#  (222108450, 'Tatiana', 'Rio de Janeiro', 24),
#  (2208473, 'Walbenir', 'Rio de Janeiro', 24),
#  (203022450, 'Ronaldo', 'Rio de Janeiro', 24),
#  (10467486, 'Carolina', 'Rio de Janeiro', 24),
#  (406555768, 'Maria Helena', 'Rio de Janeiro', 24),
#  (473819006, 'Mara', 'Rio de Janeiro', 24),
#  (79244301, 'Fabiano', 'Rio de Janeiro', 24),
#  (54899116, 'Rudá', 'Rio de Janeiro', 24),
#  (1381764, 'Pineapples', 'Rio de Janeiro', 24),
#  (8156211, 'Giovanna', 'Rio de Janeiro', 24),
#  (160469308, 'Ursula', 'Rio de Janeiro', 24),
#  (484129194, 'Clara', 'Rio de Janeiro', 24),
#  (155819967, 'Carolina', 'Rio de Janeiro', 24),
#  (135845476, 'Casa Do Mar', 'Rio de Janeiro', 24),
#  (40151333, 'Rita', 'Rio de Janeiro', 24),
#  (23488225, 'Max', 'Rio de Janeiro', 24),
#  (26005554, 'Serginho Rauen VizooBuzios', 'Rio de Janeiro', 24),
#  (406354831, 'Sheila', 'Rio de Janeiro', 24),
#  (32429803, 'Milton', 'Rio de Janeiro', 24),
#  (111551444, 'Fátima', 'Rio de Janeiro', 24),
#  (15758557, 'Francisco', 'Rio de Janeiro', 22),
#  (16023706, 'Secreto', 'Rio de Janeiro', 22),
#  (479312966, 'Emilio', 'Rio de Janeiro', 22),
#  (442712142, 'Meriele', 'Rio de Janeiro', 22),
#  (177786203, 'Jocelyn', 'Rio de Janeiro', 22),
#  (3890087, 'Peter', 'Rio de Janeiro', 22),
#  (13635061, 'Adriana', 'Rio de Janeiro', 22),
#  (330417921, 'Jeane Ormond', 'Rio de Janeiro', 21),
#  (52557989, 'Alexandre', 'Rio de Janeiro', 21),
#  (2537111, 'Barbara', 'Rio de Janeiro', 21),
#  (66513543, 'Patricia', 'Rio de Janeiro', 21),
#  (76710208, 'Alessandra', 'Rio de Janeiro', 21),
#  (260411129, 'Monica', 'Rio de Janeiro', 20),
#  (792218, 'Levy', 'Rio de Janeiro', 20),
#  (445730956, 'Apart-Hotel Convention Rio Stay', 'Rio de Janeiro', 20),
#  (2538304, 'Sonia', 'Rio de Janeiro', 20),
#  (128400147, 'Debora', 'Rio de Janeiro', 20),
#  (53588365, 'Maurício', 'Rio de Janeiro', 20),
#  (485252166, 'Erivan', 'Rio de Janeiro', 20),
#  (432143221, 'Marcus Vinicius', 'Rio de Janeiro', 20),
#  (425294959, 'Rami', 'Rio de Janeiro', 20),
#  (4873555, 'Pedro', 'Rio de Janeiro', 20),
#  (363276049, 'Tainá', 'Rio de Janeiro', 20),
#  (17325065, 'Artur', 'Rio de Janeiro', 20),
#  (451977285, 'Flávio', 'Rio de Janeiro', 20),
#  (240364027, 'Debora', 'Rio de Janeiro', 20),
#  (116135653, 'Hugo', 'Rio de Janeiro', 20),
#  (145176530, 'Marco', 'Rio de Janeiro', 20),
#  (278641760, 'Alberto', 'Rio de Janeiro', 20),
#  (163618992, 'HomeStays', 'Rio de Janeiro', 20),
#  (443318137, 'Vitor', 'Rio de Janeiro', 20),
#  (201418761, 'Carlos', 'Rio de Janeiro', 20),
#  (467605641, 'Hostel Princess', 'Rio de Janeiro', 19),
#  (213230578, 'Alexandre', 'Rio de Janeiro', 19),
#  (5532376, 'Andre', 'Rio de Janeiro', 18),
#  (171632668, 'Andre Luiz', 'Rio de Janeiro', 18),
#  (158098971, 'Myrian', 'Rio de Janeiro', 18),
#  (346082128, 'SNS Patrimonial E Serviços Ltda', 'Rio de Janeiro', 18),
#  (11389355, 'Leticia', 'Rio de Janeiro', 18),
#  (155118499, 'Phellipe', 'Rio de Janeiro', 18),
#  (89566669, 'Helena', 'Rio de Janeiro', 18),
#  (474221, 'June', 'Rio de Janeiro', 18),
#  (337762439, 'Thiago', 'Rio de Janeiro', 18),
#  (297672983, 'Hotel', 'Rio de Janeiro', 18),
#  (494964, 'Beatriz', 'Rio de Janeiro', 18),
#  (17070351, 'Carlos', 'Rio de Janeiro', 18),
#  (231159376, 'Ursula', 'Rio de Janeiro', 18),
#  (544744044, 'A2', 'Rio de Janeiro', 18),
#  (30669035, 'Aldomir', 'Rio de Janeiro', 18),
#  (164177980, 'Flávia', 'Rio de Janeiro', 18),
#  (11411976, 'Paula', 'Rio de Janeiro', 18),
#  (78598801, 'Cláudia', 'Rio de Janeiro', 18),
#  (224192, 'David', 'Rio de Janeiro', 18),
#  (5862587, 'Paula', 'Rio de Janeiro', 18),
#  (113346982, 'Stefan', 'Rio de Janeiro', 18),
#  (56337810, 'Socorro Costa', 'Rio de Janeiro', 18),
#  (271615742, 'Rita', 'Rio de Janeiro', 18),
#  (32416144, 'Alexandre', 'Rio de Janeiro', 18),
#  (510646750, 'Carlos', 'Rio de Janeiro', 18),
#  (431412286, 'Carlos Henrique', 'Rio de Janeiro', 18),
#  (444172537, 'Marie', 'Rio de Janeiro', 18),
#  (491350351, 'Fernanda', 'Rio de Janeiro', 18),
#  (39695742, 'Alberto', 'Rio de Janeiro', 18),
#  (4036979, 'Daniela', 'Rio de Janeiro', 18),
#  (475340957, 'Adv', 'Rio de Janeiro', 18),
#  (58857593, 'Luiza', 'Rio de Janeiro', 18),
#  (370073187, 'Jeferson', 'Rio de Janeiro', 18),
#  (47248185, 'Maria Luiza', 'Rio de Janeiro', 18),
#  (115075111, 'Lis', 'Rio de Janeiro', 18),
#  (13832827, 'Bernardo', 'Rio de Janeiro', 18),
#  (536600082, 'Laris', 'Rio de Janeiro', 18),
#  (423392969, 'Thiago', 'Rio de Janeiro', 18),
#  (240289, 'Maria', 'Rio de Janeiro', 18),
#  (5573690, 'Luciana', 'Rio de Janeiro', 18),
#  (494160174, 'Brunno Gabriel', 'Rio de Janeiro', 18),
#  (27149197, 'Maria Luisa', 'Rio de Janeiro', 18),
#  (10344782, 'Ney', 'Rio de Janeiro', 18),
#  (37238144, 'Rafaele Bispo', 'Rio de Janeiro', 17),
#  (116235207, 'Paulo', 'Rio de Janeiro', 16),
#  (58769289, 'Monica', 'Rio de Janeiro', 16),
#  (514115445, 'Juan Angel', 'Rio de Janeiro', 16),
#  (21648920, 'Meu Anfitrião', 'Rio de Janeiro', 16),
#  (48720390, 'Fariza', 'Rio de Janeiro', 16),
#  (266121934, 'Beatriz', 'Rio de Janeiro', 16),
#  (331210726, 'Ricardo', 'Rio de Janeiro', 16),
#  (228237182, 'Eliane', 'Rio de Janeiro', 16),
#  (95117133, 'Raissa', 'Rio de Janeiro', 16),
#  (62913860, 'Rodolfo', 'Rio de Janeiro', 16),
#  (61714845, 'Paulo', 'Rio de Janeiro', 16),
#  (442620033, 'Lidia Nayara', 'Rio de Janeiro', 16),
#  (150144948, 'Renan', 'Rio de Janeiro', 16),
#  (5866883, 'Aline', 'Rio de Janeiro', 16),
#  (64294308, 'Terezinha', 'Rio de Janeiro', 16),
#  (56179426, 'Pedro', 'Rio de Janeiro', 16),
#  (16141644, 'Patricia', 'Rio de Janeiro', 16),
#  (303124704, 'Marco', 'Rio de Janeiro', 16),
#  (98040033, 'Patricia', 'Rio de Janeiro', 16),
#  (131669310, 'Bruno & Marcos', 'Rio de Janeiro', 16),
#  (152441811, 'Thiago', 'Rio de Janeiro', 16),
#  (206038342, 'Cláudia', 'Rio de Janeiro', 16),
#  (433611205, 'Joao', 'Rio de Janeiro', 16),
#  (63099507, 'Fabiani', 'Rio de Janeiro', 16),
#  (10546234, 'Patricia', 'Rio de Janeiro', 15),
#  (61984959, 'Fabio', 'Rio de Janeiro', 15),
#  (113889162, 'Thais', 'Rio de Janeiro', 15),
#  (63899823, 'Go To Rio Rentals', 'Rio de Janeiro', 15),
#  (242965430, 'Anderson', 'Rio de Janeiro', 15),
#  (11647707, 'Rose', 'Rio de Janeiro', 15),
#  (72593893, 'Mariana', 'Rio de Janeiro', 15),
#  (336908, 'Alexandre', 'Rio de Janeiro', 15),
#  (415432275, 'Sunset Rio', 'Rio de Janeiro', 15),
#  (168203934, 'Flavia', 'Rio de Janeiro', 15),
#  (32987257, 'Angela', 'Rio de Janeiro', 15),
#  (84048033, 'Frederic', 'Rio de Janeiro', 15),
#  (15991909, 'Yona', 'Rio de Janeiro', 15),
#  (25644407, 'Vera', 'Rio de Janeiro', 15),
#  (398674687, 'Taisa E Vitor', 'Rio de Janeiro', 15),
#  (477833142, 'André', 'Rio de Janeiro', 15),
#  (475193730, 'Carolinna', 'Rio de Janeiro', 15),
#  (200621357, 'Marcela', 'Rio de Janeiro', 15),
#  (27377433, 'Celso', 'Rio de Janeiro', 15),
#  (296430347, 'Rodrigo', 'Rio de Janeiro', 14),
#  (6668899, 'Paulo Marcos', 'Rio de Janeiro', 14),
#  (652627, 'Ana', 'Rio de Janeiro', 14),
#  (130642381, 'Mahnai', 'Rio de Janeiro', 14),
#  (6213964, 'Efigenia', 'Rio de Janeiro', 14),
#  (270247199, 'Aqui Eu Rio', 'Rio de Janeiro', 14),
#  (172482654, 'Evilene', 'Rio de Janeiro', 14),
#  (506284318, 'Cristiano', 'Rio de Janeiro', 14),
#  (5967632, 'Doni', 'Rio de Janeiro', 14),
#  (497786, 'Butterfly Vanazul', 'Rio de Janeiro', 14),
#  (10564794, 'Eduardo', 'Rio de Janeiro', 14),
#  (170522649, 'João Pedro', 'Rio de Janeiro', 14),
#  (24521701, 'Fatima', 'Rio de Janeiro', 14),
#  (3746246, 'Ghizlane', 'Rio de Janeiro', 14),
#  (390140856, 'Heron', 'Rio de Janeiro', 14),
#  (248739218, 'Maria', 'Rio de Janeiro', 14),
#  (221597210, 'Marcilene', 'Rio de Janeiro', 14),
#  (171869673, 'Denise', 'Rio de Janeiro', 14),
#  (175671577, 'Top House', 'Rio de Janeiro', 14),
#  (43594754, 'AnaCecilia', 'Rio de Janeiro', 14),
#  (35297336, 'Natalia', 'Rio de Janeiro', 14),
#  (481290301, 'Wallace', 'Rio de Janeiro', 14),
#  (13501097, 'Enzo', 'Rio de Janeiro', 14),
#  (3802101, 'Katya', 'Rio de Janeiro', 14),
#  (318163118, 'Renata', 'Rio de Janeiro', 14),
#  (446253282, 'Flavia', 'Rio de Janeiro', 14),
#  (153667273, 'Fernando', 'Rio de Janeiro', 14),
#  (327244298, 'Daniel', 'Rio de Janeiro', 14),
#  (13498004, 'Fabio', 'Rio de Janeiro', 14),
#  (18117704, 'Rafael', 'Rio de Janeiro', 14),
#  (458980426, 'Eduardo', 'Rio de Janeiro', 14),
#  (167576710, 'Marco', 'Rio de Janeiro', 14),
#  (84909629, 'Juan', 'Rio de Janeiro', 14),
#  (228348887, 'Hélio', 'Rio de Janeiro', 13),
#  (202660425, 'Leila', 'Rio de Janeiro', 13),
#  (67850207, 'Tupiniquim Hostel', 'Rio de Janeiro', 13),
#  (152217261, 'Taina', 'Rio de Janeiro', 12),
#  (496656, 'Marcia  Longras', 'Rio de Janeiro', 12),
#  (543866171, 'Fabian', 'Rio de Janeiro', 12),
#  (421420448, 'Vinicius', 'Rio de Janeiro', 12),
#  (412334312, 'Raul', 'Rio de Janeiro', 12),
#  (27175729, 'Evandro', 'Rio de Janeiro', 12),
#  (302575174, 'Helmar Oliveira', 'Rio de Janeiro', 12),
#  (57163425, 'Jardel', 'Rio de Janeiro', 12),
#  (12180348, 'Diogo', 'Rio de Janeiro', 12),
#  (366265885, 'Carla', 'Rio de Janeiro', 12),
#  (15025261, 'Eliana', 'Rio de Janeiro', 12),
#  (1168587, 'Patricia', 'Rio de Janeiro', 12),
#  (475701051, 'Daiana', 'Rio de Janeiro', 12),
#  (436525910, 'Luiz Henrique', 'Rio de Janeiro', 12),
#  (10122044, 'Eduardo', 'Rio de Janeiro', 12),
#  (37427403, 'Arthur', 'Rio de Janeiro', 12),
#  (108108055, 'Maria Angela', 'Rio de Janeiro', 12),
#  (154114238, 'Breno', 'Rio de Janeiro', 12),
#  (5228078, 'Marcelo', 'Rio de Janeiro', 12),
#  (61889802, 'Breno', 'Rio de Janeiro', 12),
#  (106863172, 'Geane', 'Rio de Janeiro', 12),
#  (506608230, 'Sandra', 'Rio de Janeiro', 12),
#  (301071932, 'Mario', 'Rio de Janeiro', 12),
#  (475818840, 'Quality', 'Rio de Janeiro', 12),
#  (369641212, 'Solano Rodrigo', 'Rio de Janeiro', 12),
#  (980805, 'Henrique', 'Rio de Janeiro', 12),
#  (11607286, 'Josana', 'Rio de Janeiro', 12),
#  (490744881, 'Leonaldo', 'Rio de Janeiro', 12),
#  (225323653, 'Livia', 'Rio de Janeiro', 12),
#  (110142166, 'Lucinda', 'Rio de Janeiro', 12),
#  (14743853, 'Carlos', 'Rio de Janeiro', 12),
#  (322277570, 'Teresa', 'Rio de Janeiro', 12),
#  (3308731, 'Stay', 'Rio de Janeiro', 12),
#  (506229505, 'Alan', 'Rio de Janeiro', 12),
#  (286053300, 'Natasha', 'Rio de Janeiro', 12),
#  (10742317, 'Paula', 'Rio de Janeiro', 12),
#  (325866440, 'Enrique Y Fernanda', 'Rio de Janeiro', 12),
#  (4347269, 'Patrick', 'Rio de Janeiro', 12),
#  (225894302, 'La Casa Del Marco', 'Rio de Janeiro', 12),
#  (30717384, 'Isabela', 'Rio de Janeiro', 12),
#  (435908522, 'Jakeline', 'Rio de Janeiro', 12),
#  (5244204, 'Milla', 'Rio de Janeiro', 12),
#  (29963280, 'Paulo', 'Rio de Janeiro', 12),
#  (386204706, 'Paulo', 'Rio de Janeiro', 12),
#  (263736797, 'Carol', 'Rio de Janeiro', 12),
#  (14848679, 'Jô', 'Rio de Janeiro', 12),
#  (14232658, 'Paulo', 'Rio de Janeiro', 12),
#  (383481138, 'WelHome', 'Rio de Janeiro', 12),
#  (73791443, 'Nara', 'Rio de Janeiro', 12),
#  (299563308, 'Stefany', 'Rio de Janeiro', 12),
#  (5942159, 'Marco', 'Rio de Janeiro', 12),
#  (50893268, 'Adriana', 'Rio de Janeiro', 12),
#  (229434751, 'Gabriella', 'Rio de Janeiro', 12),
#  (12963918, 'Laura', 'Rio de Janeiro', 12),
#  (1450861, 'Leila', 'Rio de Janeiro', 12),
#  (44864535, 'Manoella', 'Rio de Janeiro', 12),
#  (427360088, 'Miriam', 'Rio de Janeiro', 12),
#  (374670667, 'Bheatriz', 'Rio de Janeiro', 12),
#  (483443544, 'Gabriel', 'Rio de Janeiro', 12),
#  (543169978, 'Victor', 'Rio de Janeiro', 12),
#  (84092121, 'Rosana', 'Rio de Janeiro', 12),
#  (187621192, 'Suzana', 'Rio de Janeiro', 12),
#  (192170777, 'Catia', 'Rio de Janeiro', 12),
#  (36640543, 'Artur', 'Rio de Janeiro', 12),
#  (12644787, 'Monica', 'Rio de Janeiro', 12),
#  (472982931, 'Anthony', 'Rio de Janeiro', 12),
#  (23847033, 'Gustavo', 'Rio de Janeiro', 12),
#  (60356266, 'Marcella', 'Rio de Janeiro', 12),
#  (23543878, 'Paulo', 'Rio de Janeiro', 12),
#  (105571030, 'Miriam', 'Rio de Janeiro', 12),
#  (46082356, 'Patrícia', 'Rio de Janeiro', 12),
#  (22579735, 'Renata', 'Rio de Janeiro', 12),
#  (346655886, 'Marcus André', 'Rio de Janeiro', 12),
#  (16623535, 'Thales', 'Rio de Janeiro', 12),
#  (195684172, 'Sergio', 'Rio de Janeiro', 12),
#  (43480511, 'Igor', 'Rio de Janeiro', 12),
#  (224118316, 'Ana Paula', 'Rio de Janeiro', 12),
#  (76210086, 'Mc Flats', 'Rio de Janeiro', 12),
#  (109885396, 'Sebastião', 'Rio de Janeiro', 12),
#  (4218951, 'Maria', 'Rio de Janeiro', 12),
#  (242968329, 'Vinicius', 'Rio de Janeiro', 12),
#  (135031039, 'Maria', 'Rio de Janeiro', 12),
#  (8527154, 'Solène', 'Rio de Janeiro', 12),
#  (551115761, 'Maria Do Socorro', 'Rio de Janeiro', 12),
#  (53461053, 'Ana Paula', 'Rio de Janeiro', 12),
#  (11032967, 'Heloisa', 'Rio de Janeiro', 12),
#  (417529749, 'Mauricio Henrique', 'Rio de Janeiro', 12),
#  (25002900, 'Elizabeth', 'Rio de Janeiro', 12),
#  (55123769, 'Mariana', 'Rio de Janeiro', 12),
#  (61163071, 'Diogo', 'Rio de Janeiro', 12),
#  (163586041, 'Teresa', 'Rio de Janeiro', 12),
#  (24766519, 'Renato', 'Rio de Janeiro', 12),
#  (523251, 'Humberto', 'Rio de Janeiro', 11),
#  (349897129, 'Nelia Pereira', 'Rio de Janeiro', 11),
#  (158933362, 'Cássia Ou Arlindo', 'Rio de Janeiro', 11),
#  (42685021, 'Roberto', 'Rio de Janeiro', 11),
#  (535841659, 'Hostel', 'Rio de Janeiro', 11),
#  (111555164, 'Juliana Bento', 'Rio de Janeiro', 11),
#  (8000736, 'Andrade', 'Rio de Janeiro', 11),
#  (76356053, 'Douglas', 'Rio de Janeiro', 10),
#  (11933341, 'Petruza', 'Rio de Janeiro', 10),
#  (9465134, 'Aline', 'Rio de Janeiro', 10),
#  (64275672, 'Adam', 'Rio de Janeiro', 10),
#  (23218244, 'Anna', 'Rio de Janeiro', 10),
#  (21743110, 'Kamila', 'Rio de Janeiro', 10),
#  (372043109, 'TrevizZo', 'Rio de Janeiro', 10),
#  (136462716, 'Oabitat', 'Rio de Janeiro', 10),
#  (160620333, 'Paulo', 'Rio de Janeiro', 10),
#  (178877979, 'Romario', 'Rio de Janeiro', 10),
#  (81153486, 'Eudes', 'Rio de Janeiro', 10),
#  (543097420, 'Roxana', 'Rio de Janeiro', 10),
#  (7955669, 'Katia Valeria', 'Rio de Janeiro', 10),
#  (277851111, 'Jorge LUIZ', 'Rio de Janeiro', 10),
#  (235468558, 'Jorge', 'Rio de Janeiro', 10),
#  (248462674, 'Arthur', 'Rio de Janeiro', 10),
#  (358323282, 'Rafael', 'Rio de Janeiro', 10),
#  (4780133, 'Lorenzo', 'Rio de Janeiro', 10),
#  (157701889, 'Caroline', 'Rio de Janeiro', 10),
#  (380142448, 'Alex', 'Rio de Janeiro', 10),
#  (69579533, 'Ana', 'Rio de Janeiro', 10),
#  (44428550, 'Carlos', 'Rio de Janeiro', 10),
#  (103275390, 'Anderson', 'Rio de Janeiro', 10),
#  (206311432, 'Igor', 'Rio de Janeiro', 10),
#  (11555320, 'Mila', 'Rio de Janeiro', 10),
#  (43038549, 'Eduardo', 'Rio de Janeiro', 10),
#  (141866453, 'Vanessa', 'Rio de Janeiro', 10),
#  (542884743, 'Wilamis', 'Rio de Janeiro', 10),
#  (320966647, 'Petruza', 'Rio de Janeiro', 10),
#  (325572562, 'Sonia Iris', 'Rio de Janeiro', 10),
#  (2989144, 'Rafael', 'Rio de Janeiro', 10),
#  (80338139, 'Cláudia', 'Rio de Janeiro', 10),
#  (13596474, 'Luisa', 'Rio de Janeiro', 10),
#  (16445274, 'Paulo', 'Rio de Janeiro', 10),
#  (6080771, 'Danielle', 'Rio de Janeiro', 10),
#  (49661699, 'Mari', 'Rio de Janeiro', 10),
#  (316824981, 'Fabiana', 'Rio de Janeiro', 10),
#  (451515499, 'Nadia', 'Rio de Janeiro', 10),
#  (4232997, 'Gabriel', 'Rio de Janeiro', 10),
#  (429604997, 'Bárbara', 'Rio de Janeiro', 10),
#  (473197861, 'Leandro', 'Rio de Janeiro', 10),
#  (96474135, 'Alzerina', 'Rio de Janeiro', 10),
#  (227246641, 'Marissol', 'Rio de Janeiro', 10),
#  (9387742, 'Leandra', 'Rio de Janeiro', 10),
#  (4947020, 'Laura', 'Rio de Janeiro', 10),
#  (23265493, 'Vinicius', 'Rio de Janeiro', 10),
#  (488619544, 'Catia Maria', 'Rio de Janeiro', 10),
#  (10214925, 'Onayr', 'Rio de Janeiro', 10),
#  (13680324, 'Lucila', 'Rio de Janeiro', 10),
#  (422476687, 'Rafael', 'Rio de Janeiro', 10),
#  (16992056, 'Irineu', 'Rio de Janeiro', 10),
#  (12498767, 'CrisSKoester', 'Rio de Janeiro', 10),
#  (5448466, 'Dan', 'Rio de Janeiro', 10),
#  (162022411, 'Patrick', 'Rio de Janeiro', 10),
#  (86774316, 'Rogerio', 'Rio de Janeiro', 10),
#  (174021180, 'Juvenal', 'Rio de Janeiro', 10),
#  (499187589, 'Yann', 'Rio de Janeiro', 10),
#  (167035172, 'Teresa', 'Rio de Janeiro', 10),
#  (66804622, 'Ana Paula', 'Rio de Janeiro', 10),
#  (197242788, 'Michael', 'Rio de Janeiro', 10),
#  (3962758, 'Thiago Luiz', 'Rio de Janeiro', 10),
#  (25341342, 'Isabella', 'Rio de Janeiro', 10),
#  (14127528, 'Débora', 'Rio de Janeiro', 10),
#  (208632582, 'Francisco', 'Rio de Janeiro', 10),
#  (319672, 'Valeria', 'Rio de Janeiro', 10),
#  (156839979, 'Diogo', 'Rio de Janeiro', 10),
#  (62933995, 'Izilda', 'Rio de Janeiro', 10),
#  (1675920, 'Dacia', 'Rio de Janeiro', 10),
#  (17244708, 'Eraldo', 'Rio de Janeiro', 10),
#  (34316296, 'Daniela', 'Rio de Janeiro', 10),
#  (372578235, 'Joao Pedro', 'Rio de Janeiro', 10),
#  (493169411, 'Daiana', 'Rio de Janeiro', 10),
#  (330044451, 'Lart', 'Rio de Janeiro', 9),
#  (1119963, 'Paulo', 'Rio de Janeiro', 9),
#  (446819945, 'Steffen', 'Rio de Janeiro', 9),
#  (110446883, 'Wagner', 'Rio de Janeiro', 9),
#  (22123293, 'Beatriz', 'Rio de Janeiro', 9),
#  (7692877, 'Georgeana & Paulino', 'Rio de Janeiro', 9),
#  (127279791, 'Ana', 'Rio de Janeiro', 9),
#  (67754861, 'Atrium', 'Rio de Janeiro', 9),
#  (77813380, 'José', 'Rio de Janeiro', 9),
#  (6687502, 'Casa Babilônia', 'Rio de Janeiro', 9),
#  (116106766, 'André', 'Rio de Janeiro', 9),
#  (387761453, 'Rafael', 'Rio de Janeiro', 9),
#  (81845329, 'Luiz', 'Rio de Janeiro', 9),
#  (519866242, 'Pontal', 'Rio de Janeiro', 9),
#  (150574794, 'Lukas', 'Rio de Janeiro', 9),
#  (112565255, 'Lis', 'Rio de Janeiro', 9),
#  (16753633, 'Pedro', 'Rio de Janeiro', 9),
#  (385889802, 'Aquinoã', 'Rio de Janeiro', 9),
#  (11739, 'Eric', 'Rio de Janeiro', 9),
#  (280138476, 'Maia', 'Rio de Janeiro', 9),
#  (68163291, 'Valder', 'Rio de Janeiro', 9),
#  (87767987, 'Giselle', 'Rio de Janeiro', 9),
#  (203267893, 'Daiane', 'Rio de Janeiro', 9),
#  (23465666, 'Luis', 'Rio de Janeiro', 9),
#  (46870690, 'Claudia', 'Rio de Janeiro', 9),
#  (182588604, 'Johana', 'Rio de Janeiro', 9),
#  (3620458, 'Sheyla E Tania', 'Rio de Janeiro', 9),
#  (48573441, 'João Felipe', 'Rio de Janeiro', 9),
#  (16068975, 'Taïs', 'Rio de Janeiro', 9),
#  (346302408, 'Rogério', 'Rio de Janeiro', 9),
#  (381221659, 'Solange', 'Rio de Janeiro', 9),
#  (261954, 'Elisa', 'Rio de Janeiro', 9),
#  (4748345, 'Suely Piana', 'Rio de Janeiro', 9),
#  (186625236, 'Yasmin', 'Rio de Janeiro', 9),
#  (78817280, 'Wagner', 'Rio de Janeiro', 9),
#  (6217672, 'Fernando', 'Rio de Janeiro', 9),
#  (13895463, 'Gabi', 'Rio de Janeiro', 9),
#  (424846414, 'Rosana', 'Rio de Janeiro', 9),
#  (170893560, 'Espaço Lumy', 'Rio de Janeiro', 9),
#  (877730, 'Ana', 'Rio de Janeiro', 9),
#  (551037642, 'Imobras', 'Rio de Janeiro', 9),
#  (32168832, 'Marcus', 'Rio de Janeiro', 9),
#  (137109572, 'Mango Tree Ipanema', 'Rio de Janeiro', 9),
#  (5743747, 'Kelly E', 'Rio de Janeiro', 9),
#  (16017168, 'Elza', 'Rio de Janeiro', 9),
#  (189757165, 'Tatiana', 'Rio de Janeiro', 9),
#  (83920896, 'Ingrid', 'Rio de Janeiro', 9),
#  (87836145, 'Ana Beatriz', 'Rio de Janeiro', 9),
#  (404052111, 'Ana', 'Rio de Janeiro', 9),
#  (88782772, 'Iccaro', 'Rio de Janeiro', 9),
#  (437600477, 'Paula', 'Rio de Janeiro', 9),
#  (110043946, 'Ana Cecilia', 'Rio de Janeiro', 9),
#  (14882007, 'Katia', 'Rio de Janeiro', 9),
#  (126519798, 'Felipe', 'Rio de Janeiro', 9),
#  (174303208, 'Àlan', 'Rio de Janeiro', 9),
#  (171663299, 'Dudu', 'Rio de Janeiro', 9),
#  (41543548, 'Marcello', 'Rio de Janeiro', 9),
#  (56224377, 'Andre', 'Rio de Janeiro', 9),
#  (264743457, 'Hannah', 'Rio de Janeiro', 9),
#  (233912196, 'Cleide', 'Rio de Janeiro', 9),
#  (184451944, 'Matteus E Luiza', 'Rio de Janeiro', 9),
#  (2704494, 'Marcio', 'Rio de Janeiro', 9),
#  (4886725, 'Carola', 'Rio de Janeiro', 9),
#  (109582975, 'Nathalia', 'Rio de Janeiro', 9),
#  (467812039, 'Agnes', 'Rio de Janeiro', 9),
#  (233643366, 'Bruna', 'Rio de Janeiro', 9),
#  (317376135, 'Pedro', 'Rio de Janeiro', 9),
#  (4232062, 'Meg', 'Rio de Janeiro', 9),
#  (184602206, 'Li', 'Rio de Janeiro', 9),
#  (69922816, 'Arnaud', 'Rio de Janeiro', 9),
#  (392745978, 'Andressa', 'Rio de Janeiro', 9),
#  (155969971, 'Ruanita Cristina', 'Rio de Janeiro', 9),
#  (10796926, 'Sugar Loft Apartments', 'Rio de Janeiro', 9),
#  (69347493, 'Thiago', 'Rio de Janeiro', 9),
#  (447555409, 'Tarsila Dina', 'Rio de Janeiro', 9),
#  (24041271, 'Luiz', 'Rio de Janeiro', 8),
#  (13903917, 'George', 'Rio de Janeiro', 8),
#  (199325340, 'Casal Carioca Aluguel Temporada', 'Rio de Janeiro', 8),
#  (374880383, 'Bossa Stay', 'Rio de Janeiro', 8),
#  (251598430, 'Elizabeth', 'Rio de Janeiro', 8),
#  (244742034, 'Denysson', 'Rio de Janeiro', 8),
#  (12351117, 'Adriana', 'Rio de Janeiro', 8),
#  (472892022, 'Flávio', 'Rio de Janeiro', 8),
#  (59068088, 'Vinícius', 'Rio de Janeiro', 8),
#  (112416504, 'Mara', 'Rio de Janeiro', 8),
#  (384046862, 'Eduarda', 'Rio de Janeiro', 8),
#  (8479954, 'Naira Beatriz', 'Rio de Janeiro', 8),
#  (14279272, 'Flavio', 'Rio de Janeiro', 8),
#  (177131210, 'Marcia Verginia', 'Rio de Janeiro', 8),
#  (14810503, 'Marcelle', 'Rio de Janeiro', 8),
#  (15536673, 'Shalimar', 'Rio de Janeiro', 8),
#  (59353344, 'Maria Das Graças', 'Rio de Janeiro', 8),
#  (333626010, 'Marylin', 'Rio de Janeiro', 8),
#  (450206297, 'Preguiça Da Boa', 'Rio de Janeiro', 8),
#  (49860452, 'Claudia', 'Rio de Janeiro', 8),
#  (48898255, 'Camila', 'Rio de Janeiro', 8),
#  (4168266, 'CabanaCopa', 'Rio de Janeiro', 8),
#  (331576610, 'Geise', 'Rio de Janeiro', 8),
#  (33296691, 'Elisa', 'Rio de Janeiro', 8),
#  (45156129, 'Jaden Matt', 'Rio de Janeiro', 8),
#  (394983020, 'Roberta', 'Rio de Janeiro', 8),
#  (4884558, 'Anselmo', 'Rio de Janeiro', 8),
#  (6422051, 'CrisTemporada', 'Rio de Janeiro', 8),
#  (7834157, 'Andrea', 'Rio de Janeiro', 8),
#  (67256046, 'Maximilliam', 'Rio de Janeiro', 8),
#  (18136498, 'Cassia', 'Rio de Janeiro', 8),
#  (125989559, 'Bruno', 'Rio de Janeiro', 8),
#  (29678743, 'Baldô', 'Rio de Janeiro', 8),
#  (203289711, 'Priscilla', 'Rio de Janeiro', 8),
#  (351860049, 'Fabio Henrique', 'Rio de Janeiro', 8),
#  (5020460, 'Samantha', 'Rio de Janeiro', 8),
#  (1648634, 'Jose', 'Rio de Janeiro', 8),
#  (27462821, 'Lili', 'Rio de Janeiro', 8),
#  (491946086, 'Matheus', 'Rio de Janeiro', 8),
#  (228016212, 'Elizabeth', 'Rio de Janeiro', 8),
#  (9967131, 'Aline', 'Rio de Janeiro', 8),
#  (4428126, 'Cesar', 'Rio de Janeiro', 8),
#  (160440618, 'Elaine', 'Rio de Janeiro', 8),
#  (45269832, 'Nelia', 'Rio de Janeiro', 8),
#  (491454926, 'Marcia', 'Rio de Janeiro', 8),
#  (46809360, 'Vilma', 'Rio de Janeiro', 8),
#  (274871877, 'Luiz Fernando', 'Rio de Janeiro', 8),
#  (14583404, 'Soraya', 'Rio de Janeiro', 8),
#  (4233652, 'Saionara', 'Rio de Janeiro', 8),
#  (8616615, 'Jacqueline', 'Rio de Janeiro', 8),
#  (54538377, 'Igor', 'Rio de Janeiro', 8),
#  (210818814, 'Claudia', 'Rio de Janeiro', 8),
#  (275440667, 'Gustavo', 'Rio de Janeiro', 8),
#  (16545585, 'Celia', 'Rio de Janeiro', 8),
#  (4832097, 'Celi', 'Rio de Janeiro', 8),
#  (105226518, 'Rio World Luxury', 'Rio de Janeiro', 8),
#  (55248222, 'Filipi E Jessica', 'Rio de Janeiro', 8),
#  (44859919, 'Sergio', 'Rio de Janeiro', 8),
#  (73847209, 'Thérèse', 'Rio de Janeiro', 8),
#  (14246086, 'Patricia', 'Rio de Janeiro', 8),
#  (134405287, 'Francisco', 'Rio de Janeiro', 8),
#  (1558302, 'Joao Pedro', 'Rio de Janeiro', 8),
#  (206684373, 'Samanta', 'Rio de Janeiro', 8),
#  (111165788, 'Georges', 'Rio de Janeiro', 8),
#  (547680127, 'Brenda', 'Rio de Janeiro', 8),
#  (84682646, 'Ligia', 'Rio de Janeiro', 8),
#  (68850265, 'Bette', 'Rio de Janeiro', 8),
#  (103805176, 'Heloisa', 'Rio de Janeiro', 8),
#  (74978304, 'Maidy', 'Rio de Janeiro', 8),
#  (72865722, 'Josy', 'Rio de Janeiro', 8),
#  (475372439, 'Maria', 'Rio de Janeiro', 8),
#  (12023444, 'Rachel', 'Rio de Janeiro', 8),
#  (89886135, 'Genivaldo', 'Rio de Janeiro', 8),
#  (308989912, 'Elzi', 'Rio de Janeiro', 8),
#  (10649149, 'Edna', 'Rio de Janeiro', 8),
#  (120975154, 'Vera', 'Rio de Janeiro', 8),
#  (241334, 'Andrea', 'Rio de Janeiro', 8),
#  (7305490, 'Rodrigo', 'Rio de Janeiro', 8),
#  (621406, 'Alexandre', 'Rio de Janeiro', 8),
#  (182590655, 'Linda', 'Rio de Janeiro', 8),
#  (302960741, 'Solar', 'Rio de Janeiro', 8),
#  (72311432, 'Juliane', 'Rio de Janeiro', 8),
#  (416566970, 'Augusto', 'Rio de Janeiro', 8),
#  (418348558, 'Eliania', 'Rio de Janeiro', 8),
#  (4506032, 'Maria', 'Rio de Janeiro', 8),
#  (378111934, 'Luiz', 'Rio de Janeiro', 8),
#  (173357710, 'Silvania', 'Rio de Janeiro', 8),
#  (376765302, 'Felipe', 'Rio de Janeiro', 8),
#  (508835814, 'Rio To Stay', 'Rio de Janeiro', 8),
#  (50435064, 'Paula', 'Rio de Janeiro', 8),
#  (173836079, 'Roberta', 'Rio de Janeiro', 8),
#  (104569146, 'Caio', 'Rio de Janeiro', 8),
#  (3701369, 'Eduardo', 'Rio de Janeiro', 8),
#  (376725829, 'Claudine', 'Rio de Janeiro', 8),
#  (49267693, 'Victor', 'Rio de Janeiro', 8),
#  (9240616, 'Nils', 'Rio de Janeiro', 8),
#  (466355464, 'Guilherme', 'Rio de Janeiro', 8),
#  (57248858, 'Zlatko', 'Rio de Janeiro', 8),
#  (64757298, 'Rosário', 'Rio de Janeiro', 8),
#  (78463246, 'Thiago', 'Rio de Janeiro', 8),
#  (243884726, 'Alessandra', 'Rio de Janeiro', 8),
#  (258999505, 'Aldo', 'Rio de Janeiro', 8),
#  (134569719, 'Luiza', 'Rio de Janeiro', 8),
#  (36485470, 'Roberto', 'Rio de Janeiro', 8),
#  (6836857, 'Vanessa', 'Rio de Janeiro', 8),
#  (517386494, 'Beach House Gigóia', 'Rio de Janeiro', 8),
#  (79266748, 'Little', 'Rio de Janeiro', 8),
#  (261848845, 'Arosa', 'Rio de Janeiro', 8),
#  (95906598, 'Décio Lacerda', 'Rio de Janeiro', 8),
#  (62435208, 'Jônata', 'Rio de Janeiro', 8),
#  (325635866, 'Simone', 'Rio de Janeiro', 8),
#  (72296387, 'Wilson', 'Rio de Janeiro', 8),
#  (50442621, 'Flávia', 'Rio de Janeiro', 8),
#  (13299199, 'André', 'Rio de Janeiro', 8),
#  (470173166, 'Marco', 'Rio de Janeiro', 8),
#  (70426798, 'Márcia', 'Rio de Janeiro', 8),
#  (5286153, 'Pablo', 'Rio de Janeiro', 8),
#  (6504705, 'Philippe', 'Rio de Janeiro', 8),
#  (23342524, 'Adriana', 'Rio de Janeiro', 8),
#  (32266792, 'Sandro', 'Rio de Janeiro', 8),
#  (9699300, 'Elisa', 'Rio de Janeiro', 8),
#  (230557551, 'Cristiane', 'Rio de Janeiro', 8),
#  (11933736, 'Luiz', 'Rio de Janeiro', 8),
#  (129454806, 'Johan & Barbara', 'Rio de Janeiro', 8),
#  (31478078, 'Victor', 'Rio de Janeiro', 8),
#  (426256392, 'Ipanema Club', 'Rio de Janeiro', 8),
#  (378156518, 'Mellany', 'Rio de Janeiro', 8),
#  (88757714, 'Ana Claudia', 'Rio de Janeiro', 8),
#  (438818077, 'Luccas', 'Rio de Janeiro', 8),
#  (23833600, 'Lucas', 'Rio de Janeiro', 8),
#  (64517824, 'José Franklin', 'Rio de Janeiro', 8),
#  (23168259, 'Dafne', 'Rio de Janeiro', 8),
#  (532098610, 'Marcelo', 'Rio de Janeiro', 8),
#  (4708373, 'Andres', 'Rio de Janeiro', 8),
#  (1208327, 'Christian', 'Rio de Janeiro', 8),
#  (385601473, 'Higor', 'Rio de Janeiro', 8),
#  (17169917, 'Ingrid', 'Rio de Janeiro', 8),
#  (226872366, 'Diogo', 'Rio de Janeiro', 8),
#  (193270591, 'Caroline', 'Rio de Janeiro', 8),
#  (2993489, 'Adriana Tajtelbaum E Daniel', 'Rio de Janeiro', 8),
#  (392265608, 'Sérgio', 'Rio de Janeiro', 8),
#  (443582873, 'Arthur', 'Rio de Janeiro', 8),
#  (59089584, 'Luiz', 'Rio de Janeiro', 8),
#  (235977095, 'Luiz', 'Rio de Janeiro', 8),
#  (30729912, 'Marcelo', 'Rio de Janeiro', 8),
#  (51321275, 'Gustavo E Gabriela', 'Rio de Janeiro', 8),
#  (82491056, 'Raphael', 'Rio de Janeiro', 8),
#  (388598443, 'Sidney', 'Rio de Janeiro', 8),
#  (392769753, 'Amanda', 'Rio de Janeiro', 8),
#  (15738587, 'Claudia', 'Rio de Janeiro', 8),
#  (4501614, 'Patricia', 'Rio de Janeiro', 8),
#  (3535482, 'Sergio', 'Rio de Janeiro', 8),
#  (1846563, 'Edgar', 'Rio de Janeiro', 8),
#  (16040532, 'AlexRioFlats® - Alex & Danielle', 'Rio de Janeiro', 8),
#  (240682893, 'Luciano', 'Rio de Janeiro', 8),
#  (158742579, 'Eberson', 'Rio de Janeiro', 7),
#  (156237325, 'Thiago', 'Rio de Janeiro', 7),
#  (15221271, 'Robson', 'Rio de Janeiro', 7),
#  (10548523, 'Antonio', 'Rio de Janeiro', 7),
#  (477415028, 'Rio 222', 'Rio de Janeiro', 7),
#  (61571618, 'Cesar', 'Rio de Janeiro', 7),
#  (109001343, 'Jorge', 'Rio de Janeiro', 7),
#  (6005451, 'Tereza', 'Rio de Janeiro', 7),
#  (17175278, 'Elcio', 'Rio de Janeiro', 7),
#  (37776540, 'Mariana', 'Rio de Janeiro', 7),
#  (59013736, 'Marcio', 'Rio de Janeiro', 7),
#  (27531233, 'Tiago', 'Rio de Janeiro', 7),
#  (193205371, 'Victor', 'Rio de Janeiro', 7),
#  (163240238, 'Amanda', 'Rio de Janeiro', 7),
#  (270380307, 'Priscilla', 'Rio de Janeiro', 7),
#  (489468090, 'Leni', 'Rio de Janeiro', 7),
#  (323842917, 'HAna Hostel Albergues E', 'Rio de Janeiro', 7),
#  (549301884, 'Jully', 'Rio de Janeiro', 7),
#  (92034724, 'Adriana', 'Rio de Janeiro', 7),
#  (4613553, 'Frank', 'Rio de Janeiro', 7),
#  (235670926, 'Diogo', 'Rio de Janeiro', 7),
#  (490346774, 'Helena', 'Rio de Janeiro', 7),
#  (474387007, 'Ricardo', 'Rio de Janeiro', 7),
#  (503995, '❤️ BrUx ❤️', 'Rio de Janeiro', 7),
#  (234275790, 'Forest Club', 'Rio de Janeiro', 7),
#  (19311663, 'Ana', 'Rio de Janeiro', 7),
#  (635510, 'Gilberto', 'Rio de Janeiro', 7),
#  (428418079, 'Ingher', 'Rio de Janeiro', 7),
#  (59519391, 'Márcio', 'Rio de Janeiro', 7),
#  (13639219, 'Alex', 'Rio de Janeiro', 7),
#  (53714117, 'Rayan', 'Rio de Janeiro', 7),
#  (421876226, 'Natália', 'Rio de Janeiro', 7),
#  (5165851, 'Manfred', 'Rio de Janeiro', 7),
#  (335170968, 'Christine', 'Rio de Janeiro', 7),
#  (2948186, 'Rodrigo', 'Rio de Janeiro', 7),
#  (1429181, 'Samuel', 'Rio de Janeiro', 7),
#  (15060606, 'Nelson', 'Rio de Janeiro', 6),
#  (462931014, 'Camila', 'Rio de Janeiro', 6),
#  (425723946, 'Laura', 'Rio de Janeiro', 6),
#  (461500234, 'Paulo', 'Rio de Janeiro', 6),
#  (468900451, 'Simone', 'Rio de Janeiro', 6),
#  (53918534, 'Quiá', 'Rio de Janeiro', 6),
#  (22022407, 'Edson', 'Rio de Janeiro', 6),
#  (13568538, 'Natalia', 'Rio de Janeiro', 6),
#  (263499518, 'LSH Lifestyle Hotel', 'Rio de Janeiro', 6),
#  (493954441, 'Ivone Lopes', 'Rio de Janeiro', 6),
#  (35589433, 'Lenna', 'Rio de Janeiro', 6),
#  (2903813, 'Lucia', 'Rio de Janeiro', 6),
#  (152375973, 'Allexis', 'Rio de Janeiro', 6),
#  (29593595, 'Sweet Homes Rio', 'Rio de Janeiro', 6),
#  (336208953, 'Alexandre', 'Rio de Janeiro', 6),
#  (110636072, 'Rosilene Schneider', 'Rio de Janeiro', 6),
#  (468265650, 'Rômulo', 'Rio de Janeiro', 6),
#  (498791117, 'Marcos', 'Rio de Janeiro', 6),
#  (52527684, 'Claudia', 'Rio de Janeiro', 6),
#  (336118581, 'Marcela', 'Rio de Janeiro', 6),
#  (500892, 'Rafael', 'Rio de Janeiro', 6),
#  (403781, 'Dieine', 'Rio de Janeiro', 6),
#  (2125175, 'Eliete', 'Rio de Janeiro', 6),
#  (380179383, 'Francesco', 'Rio de Janeiro', 6),
#  (100693784, 'Aida', 'Rio de Janeiro', 6),
#  (387810254, 'Vivian', 'Rio de Janeiro', 6),
#  (148198904, 'Marco É Sara', 'Rio de Janeiro', 6),
#  (123078441, 'Sonia Regina', 'Rio de Janeiro', 6),
#  (86573677, 'Nina', 'Rio de Janeiro', 6),
#  (33603644, 'José Marcos', 'Rio de Janeiro', 6),
#  (205028918, 'Arlene', 'Rio de Janeiro', 6),
#  (293254659, 'Anna Paula', 'Rio de Janeiro', 6),
#  (541299749, 'Yohan', 'Rio de Janeiro', 6),
#  (218304025, 'Vanessa', 'Rio de Janeiro', 6),
#  (28095018, 'Bruno', 'Rio de Janeiro', 6),
#  (15637811, 'Antonia', 'Rio de Janeiro', 6),
#  (71106077, 'Filipe', 'Rio de Janeiro', 6),
#  (479035184, 'Karina', 'Rio de Janeiro', 6),
#  (7386906, 'Alexandre', 'Rio de Janeiro', 6),
#  (497970207, 'Bernardo', 'Rio de Janeiro', 6),
#  (391637592, 'Mouzart', 'Rio de Janeiro', 6),
#  (10651339, 'Carlos', 'Rio de Janeiro', 6),
#  (344170057, 'Viviane & Jefferson', 'Rio de Janeiro', 6),
#  (262323238, 'Yanne', 'Rio de Janeiro', 6),
#  (336550380, 'Michel', 'Rio de Janeiro', 6),
#  (11109524, 'Marilene', 'Rio de Janeiro', 6),
#  (396858614, 'Joice', 'Rio de Janeiro', 6),
#  (370124074, 'Pedro Henrique', 'Rio de Janeiro', 6),
#  (305500093, 'Juliana', 'Rio de Janeiro', 6),
#  (466551982, 'José Gonçalves', 'Rio de Janeiro', 6),
#  (214698118, 'Josy', 'Rio de Janeiro', 6),
#  (285302898, 'Venit', 'Rio de Janeiro', 6),
#  (144161370, 'Carmen', 'Rio de Janeiro', 6),
#  (214762358, 'Claudio', 'Rio de Janeiro', 6),
#  (475149717, 'Joao Paulo', 'Rio de Janeiro', 6),
#  (33453841, 'Julius', 'Rio de Janeiro', 6),
#  (3167047, 'Vergilio', 'Rio de Janeiro', 6),
#  (498513577, 'Alexandre', 'Rio de Janeiro', 6),
#  (448235602, 'José Eduardo Feitosa', 'Rio de Janeiro', 6),
#  (517311350, 'Marc', 'Rio de Janeiro', 6),
#  (325896188, 'Marcelo', 'Rio de Janeiro', 6),
#  (105113529, 'Urca Hotel', 'Rio de Janeiro', 6),
#  (137179064, 'Juliana', 'Rio de Janeiro', 6),
#  (106411720, 'Marcelo', 'Rio de Janeiro', 6),
#  (189535285, 'Reserva', 'Rio de Janeiro', 6),
#  (4729785, 'Alexandre', 'Rio de Janeiro', 6),
#  (63761642, 'Paulo Junior', 'Rio de Janeiro', 6),
#  (39171969, 'Victor', 'Rio de Janeiro', 6),
#  (107999052, 'Maria De Fátima', 'Rio de Janeiro', 6),
#  (15152328, 'Marcelo', 'Rio de Janeiro', 6),
#  (257649804, 'Yasmin', 'Rio de Janeiro', 6),
#  (499354177, 'Igor', 'Rio de Janeiro', 6),
#  (445679619, 'Stael', 'Rio de Janeiro', 6),
#  (97960114, 'Pedro Henrique', 'Rio de Janeiro', 6),
#  (466760781, 'AcuaRIO', 'Rio de Janeiro', 6),
#  (162784922, 'Luana', 'Rio de Janeiro', 6),
#  (57691342, 'Anna', 'Rio de Janeiro', 6),
#  (38778321, 'Gilda', 'Rio de Janeiro', 6),
#  (493348793, 'Magia', 'Rio de Janeiro', 6),
#  (218582035, 'Adeildo & Sheila', 'Rio de Janeiro', 6),
#  (50596951, 'Miguel', 'Rio de Janeiro', 6),
#  (62895661, 'Roberta', 'Rio de Janeiro', 6),
#  (127689220, 'Ana Clara', 'Rio de Janeiro', 6),
#  (436113142, 'Cleiton', 'Rio de Janeiro', 6),
#  (105963434, 'Luis', 'Rio de Janeiro', 6),
#  (460391194, 'Bruna De Menezes', 'Rio de Janeiro', 6),
#  (25571291, 'Ricardo', 'Rio de Janeiro', 6),
#  (44424958, 'Antonio', 'Rio de Janeiro', 6),
#  (477747397, 'Leandro', 'Rio de Janeiro', 6),
#  (112143982, 'Luiz Antonio', 'Rio de Janeiro', 6),
#  (432890407, 'Elisiane', 'Rio de Janeiro', 6),
#  (300339043, 'Claudia', 'Rio de Janeiro', 6),
#  (10207502, 'Cláudia', 'Rio de Janeiro', 6),
#  (94707835, 'Rose', 'Rio de Janeiro', 6),
#  (2350092, 'Geraldo', 'Rio de Janeiro', 6),
#  (93710870, 'Mere', 'Rio de Janeiro', 6),
#  (41313259, 'Ines', 'Rio de Janeiro', 6),
#  (57057712, 'Bruno', 'Rio de Janeiro', 6),
#  (7614714, 'Lya', 'Rio de Janeiro', 6),
#  (175665960, 'Elis', 'Rio de Janeiro', 6),
#  (479918990, 'Mark', 'Rio de Janeiro', 6),
#  (95754481, 'Diogo', 'Rio de Janeiro', 6),
#  (24232355, 'Sueli', 'Rio de Janeiro', 6),
#  (78960552, 'Cristina', 'Rio de Janeiro', 6),
#  (489090622, 'Local', 'Rio de Janeiro', 6),
#  (10555251, 'Task Brasil', 'Rio de Janeiro', 6),
#  (40952239, 'Andrea', 'Rio de Janeiro', 6),
#  (434348285, 'Thiago', 'Rio de Janeiro', 6),
#  (38683129, 'Rosario', 'Rio de Janeiro', 6),
#  (25663032, 'Barbara', 'Rio de Janeiro', 6),
#  (14805617, 'Alessandra', 'Rio de Janeiro', 6),
#  (4060449, 'Rodrigo', 'Rio de Janeiro', 6),
#  (523852326, 'Ju Carvalho', 'Rio de Janeiro', 6),
#  (4104868, 'Rommel', 'Rio de Janeiro', 6),
#  (106134540, 'Sergio', 'Rio de Janeiro', 6),
#  (429983094, 'Hugo', 'Rio de Janeiro', 6),
#  (125395131, 'Jose', 'Rio de Janeiro', 6),
#  (11133417, 'Suzana', 'Rio de Janeiro', 6),
#  (415361942, 'Souza', 'Rio de Janeiro', 6),
#  (277211468, 'Leticia', 'Rio de Janeiro', 6),
#  (7965481, 'Luciana', 'Rio de Janeiro', 6),
#  (54233024, 'Laurent', 'Rio de Janeiro', 6),
#  (367887912, 'Sveglia', 'Rio de Janeiro', 6),
#  (54747965, 'Detlev', 'Rio de Janeiro', 6),
#  (527801472, 'Carlos Henrique', 'Rio de Janeiro', 6),
#  (313658615, 'Marina', 'Rio de Janeiro', 6),
#  (43571889, 'Marcia', 'Rio de Janeiro', 6),
#  (159072186, 'Erika', 'Rio de Janeiro', 6),
#  (1172595, 'Rafaela', 'Rio de Janeiro', 6),
#  (110548500, 'Pedro Enrique', 'Rio de Janeiro', 6),
#  (210041079, 'Goya', 'Rio de Janeiro', 6),
#  (387911161, 'Glayse', 'Rio de Janeiro', 6),
#  (243303614, 'Luiz', 'Rio de Janeiro', 6),
#  (297450975, 'Selina', 'Rio de Janeiro', 6),
#  (143228599, 'Fernanda', 'Rio de Janeiro', 6),
#  (537934961, 'Enrico', 'Rio de Janeiro', 6),
#  (42515438, 'Cristiane', 'Rio de Janeiro', 6),
#  (316921706, 'Paulo', 'Rio de Janeiro', 6),
#  (500342204, 'Raíssa', 'Rio de Janeiro', 6),
#  (2960024, 'Vanessa', 'Rio de Janeiro', 6),
#  (81680798, 'Amenik', 'Rio de Janeiro', 6),
#  (94791318, 'Lívia', 'Rio de Janeiro', 6),
#  (389379436, 'Beatriz', 'Rio de Janeiro', 6),
#  (1267196, 'Eduardo', 'Rio de Janeiro', 6),
#  (319260685, 'Carol', 'Rio de Janeiro', 6),
#  (4215606, 'Eduardo', 'Rio de Janeiro', 6),
#  (98901610, 'Lorrayne', 'Rio de Janeiro', 6),
#  (471532909, 'Mara', 'Rio de Janeiro', 6),
#  (21416036, 'Ceci', 'Rio de Janeiro', 6),
#  (22307717, 'Tauli', 'Rio de Janeiro', 6),
#  (9632245, 'Rayani', 'Rio de Janeiro', 6),
#  (460275003, 'Enzo', 'Rio de Janeiro', 6),
#  ...]

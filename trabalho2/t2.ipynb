# %% [markdown]
# # Trabalho 2 de Banco de Dados - SCC0240

# %%
import pandas as pd

# %% [markdown]
# ## Imports e Testes
# Checando se tudo está funcionando

# %%
from ipywidgets import interact 
import ipywidgets as widgets
from sqlalchemy import create_engine

# %%
# %load_ext sql

engine = create_engine('postgresql://postgres:postgres@localhost/postgres')
# %sql postgresql://postgres:postgres@localhost/postgres
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting to 'postgresql://postgres:***@localhost/postgres'

# %% [markdown]
# Change displaylimit

# %%
# %config SqlMagic.displaylimit = 20
# %config SqlMagic.style = 'MARKDOWN'

# %%
# %%sql
# SELECT Current_database();
# Out:
# Running query in 'postgresql://postgres:***@localhost/postgres'
# 1 rows affected.
# | current_database |
# | :--------------: |
# |     postgres     |

# %% [markdown]
# ## 3. Criação e carga de tabelas

# %% [markdown]
# ### 1. Criação de tabelas do Airbnb

# %%
# %sql --file sql/3CriacaoAirbnb.sql
# Out:
# Running query in 'postgresql://postgres:***@localhost/postgres'
# ||
# ||

# %% [markdown]
# ### 2. Carga de tabelas do Airbnb

# %%
! psql -U postgres -c "\copy Reviews from /tmp/reviews.csv delimiter ',' CSV HEADER;"
! psql -U postgres -c "\copy Listings from /tmp/listings.csv delimiter ',' CSV HEADER;"
! psql -U postgres -c "\copy Calendar from /tmp/calendar.csv delimiter ',' CSV HEADER;"
# Out:
# COPY 402663
# COPY 36008
# COPY 13145595

# %%
# %%sql
# UPDATE Listings
# SET name_ = CONCAT(
#     SPLIT_PART(name_, '·', 1),
#     SPLIT_PART(name_, '·', 3),
#     SPLIT_PART(name_, '·', 4),
#     SPLIT_PART(name_, '·', 5)
# )
# Out:
# Running query in 'postgresql://postgres:***@localhost/postgres'
# 36008 rows affected.
# ||
# ||

# %%
# %%sql
# SELECT COUNT(id), name_, host_id
# FROM Listings
# GROUP BY name_, host_id
# ORDER BY count DESC
# Out:
# Running query in 'postgresql://postgres:***@localhost/postgres'
# 32519 rows affected.
# | count |                              name_                              |  host_id  |
# | :---: | :-------------------------------------------------------------: | :-------: |
# |   32  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    |  6000862  |
# |   27  |     Rental unit in Rio de Janeiro  1 bedroom  1 bed  1 bath     | 371026651 |
# |   22  | Serviced apartment in Barra da Tijuca  1 bedroom  1 bed  1 bath |  46664224 |
# |   21  |          Rental unit in Rio de Janeiro  5 beds  2 baths         |  47584281 |
# |   21  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    |  1982737  |
# |   20  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    |  30165706 |
# |   20  |  Serviced apartment in Rio de Janeiro  1 bedroom  1 bed  1 bath |  46664224 |
# |   19  |       Rental unit in Copacabana  1 bedroom  2 beds  1 bath      |  6000862  |
# |   17  |     Rental unit in Rio de Janeiro  1 bedroom  1 bed  1 bath     |  6000862  |
# |   16  |    Rental unit in Rio de Janeiro  2 bedrooms  2 beds  2 baths   | 341887136 |
# |   16  |          Rental unit in Rio de Janeiro  2 beds  2 baths         | 341887136 |
# |   14  |          Condo in Jacarepaguá  1 bedroom  1 bed  1 bath         | 331210726 |
# |   13  |           Rental unit in Rio de Janeiro  1 bed  1 bath          |  4307081  |
# |   13  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    |  74463624 |
# |   12  |    Rental unit in Rio de Janeiro  2 bedrooms  5 beds  2 baths   |  47584281 |
# |   12  |       Rental unit in Rio de Janeiro  1 bed  1 private bath      | 166827375 |
# |   11  |     Rental unit in Rio de Janeiro  1 bedroom  1 bed  1 bath     |  21365765 |
# |   11  |      Rental unit in Rio de Janeiro  7 beds  2 shared baths      | 481290301 |
# |   11  |     Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath    | 347487511 |
# |   11  |     Rental unit in Rio de Janeiro  1 bedroom  1 bed  1 bath     |  30165706 |
# Truncated to displaylimit of 20.

# %% [markdown]
# ### 3. Criação e carga de Tabelas mapeadas pelo MRel

# %%
# %%capture
# %sql --file sql/2CriacaoTabelasMRel.sql

# %sql --file sql/3CargaTabelasMRel.sql
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
#  * postgresql://postgres:***@localhost/trabbd
# 36008 rows affected.
# 156 rows affected.
# 32519 rows affected.
# 21980 rows affected.
# 703796 rows affected.
# 6080206 rows affected.
# []

# %%
# %sql SELECT * FROM pg_catalog.pg_tables;
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 85 rows affected.
# [('pg_catalog', 'pg_statistic', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_type', 'postgres', None, True, False, False, False),
#  ('public', 'reviews', 'postgres', None, False, False, False, False),
#  ('public', 'listings', 'postgres', None, True, False, False, False),
#  ('public', 'calendar', 'postgres', None, False, False, False, False),
#  ('public', 'propriedades', 'postgres', None, True, False, False, False),
#  ('public', 'localizacoes', 'postgres', None, True, False, False, False),
#  ('public', 'usuarios', 'postgres', None, True, False, False, False),
#  ('public', 'mensagens', 'postgres', None, False, False, False, False),
#  ('public', 'locacao', 'postgres', None, True, False, False, False),
#  ('public', 'pontosinteresse', 'postgres', None, True, False, False, False),
#  ('public', 'fotos', 'postgres', None, True, False, False, False),
#  ('public', 'quartos', 'postgres', None, True, False, False, False),
#  ('public', 'comodidades', 'postgres', None, True, False, False, False),
#  ('public', 'contas', 'postgres', None, True, False, False, False),
#  ('public', 'datasdisponiveis', 'postgres', None, True, False, False, False),
#  ('public', 'regras', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_foreign_server', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_authid', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_statistic_ext_data', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_user_mapping', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_subscription', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_attribute', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_proc', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_class', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_attrdef', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_constraint', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_inherits', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_index', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_operator', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_opfamily', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_opclass', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_am', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_amop', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_amproc', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_language', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_largeobject_metadata', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_aggregate', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_largeobject', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_statistic_ext', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_rewrite', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_trigger', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_event_trigger', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_description', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_cast', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_enum', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_namespace', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_conversion', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_depend', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_database', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_db_role_setting', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_tablespace', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_pltemplate', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_auth_members', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_shdepend', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_shdescription', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_ts_config', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_ts_config_map', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_ts_dict', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_ts_parser', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_ts_template', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_extension', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_foreign_data_wrapper', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_foreign_table', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_policy', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_replication_origin', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_default_acl', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_init_privs', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_seclabel', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_shseclabel', 'postgres', 'pg_global', True, False, False, False),
#  ('pg_catalog', 'pg_collation', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_partitioned_table', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_range', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_transform', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_sequence', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_publication', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_publication_rel', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_subscription_rel', 'postgres', None, True, False, False, False),
#  ('information_schema', 'sql_packages', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_features', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_implementation_info', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_parts', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_languages', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_sizing', 'postgres', None, False, False, False, False),
#  ('information_schema', 'sql_sizing_profiles', 'postgres', None, False, False, False, False)]

# %% [markdown]
# ## 4. Consultas

# %% [markdown]
# ### Exercício 6

# %%
# %sql SELECT * FROM Propriedades ORDER BY RANDOM() LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 10 rows affected.
# [(22127, 'Rental unit in Rio de Janeiro  1 bedroom  3 beds  1 bath', None, 50, 235745144, None, None, 600.0, None, 5, None, None, None, None, None),
#  (1910, 'Condo in Rio de Janeiro  1 bedroom  2 beds  1.5 baths', None, 99, 28016674, None, None, 5886.0, None, 4, None, None, None, None, None),
#  (4191, 'Home in Rio de Janeiro  1 bedroom  1 bed  1 bath', None, 98, 214796650, None, None, 129.0, None, 1, None, None, None, None, None),
#  (20215, 'Rental unit in Rio de Janeiro  1 bedroom  2 beds  1 bath', None, 50, 36174304, None, None, 750.0, None, 3, None, None, None, None, None),
#  (14746, 'Rental unit in Rio de Janeiro  1 bed  1 bath', None, 49, 29197201, None, None, 145.0, None, 2, None, None, None, None, None),
#  (15985, 'Rental unit in Rio de Janeiro  1 bed  1.5 baths', None, 41, 125147687, None, None, 532.0, None, 1, None, None, None, None, None),
#  (5643, 'Home in Rio de Janeiro  6 beds  3 baths', None, 115, 486901528, None, None, 1800.0, None, 1, None, None, None, None, None),
#  (19492, 'Rental unit in Rio de Janeiro  1 bedroom  1 bed  2 baths', None, 34, 39655880, None, None, 1466.0, None, 3, None, None, None, None, None),
#  (9621, 'Rental unit in Copacabana  1 bedroom  3 beds  1 bath', None, 41, 47629070, None, None, 902.0, None, 2, None, None, None, None, None),
#  (29242, 'Rental unit in Rio de Janeiro  3 beds  2.5 baths', None, 115, 54724963, None, None, 1538.0, None, 5, None, None, None, None, None)]

# %%
sql_query = """
SELECT
    CASE
        WHEN minnoites = 1 THEN '1'
        WHEN minnoites = 2 THEN '2'
        WHEN minnoites = 3 THEN '3'
        WHEN minnoites = 4 THEN '4'
        WHEN minnoites >= 5 THEN '5 ou mais'
    END AS MinNoites,
    COUNT(*) AS NumPropriedades
FROM
    Propriedades
GROUP BY
    CASE
        WHEN minnoites = 1 THEN '1'
        WHEN minnoites = 2 THEN '2'
        WHEN minnoites = 3 THEN '3'
        WHEN minnoites = 4 THEN '4'
        WHEN minnoites >= 5 THEN '5 ou mais'
    END
ORDER BY
    MinNoites;
"""

# %sql $sql_query
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 5 rows affected.
# [('1', 8008), ('2', 9390), ('3', 7235), ('4', 2674), ('5 ou mais', 5212)]

# %%
# %sql SELECT COUNT(*) AS NumeroLocalizacoes FROM Localizacoes;
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 1 rows affected.
# [(156,)]

# %% [markdown]
# ### Exercício 7

# %%
# %sql --file sql/ex7.sql
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
# 12 rows affected.
# [(1.0, 1340.9947690174577),
#  (2.0, 1336.956078758397),
#  (3.0, 1252.009881718175),
#  (4.0, 1297.3154039455223),
#  (5.0, 1291.2594455291928),
#  (6.0, 1301.0582977855458),
#  (7.0, 1360.7305691696188),
#  (8.0, 1363.7079832535787),
#  (9.0, 1383.6694099826725),
#  (10.0, 1443.2146198132302),
#  (11.0, 1436.4975684948815),
#  (12.0, 1406.9930366870558)]

# %% [markdown]
# ### Exercício 8

# %%
sql_query = """
SELECT
    U.ID,
    U.Nome, 
    L.Cidade,
    COUNT(P.ID) AS QuantidadeDeImoveis
FROM 
    Usuarios U
JOIN 
    Localizacoes L ON U.IDLocalizacao = L.ID
JOIN 
    Propriedades P ON U.ID = P.IDAnfitriao
GROUP BY 
    U.ID, U.Nome, L.Cidade
HAVING 
    COUNT(P.ID) >= 3
ORDER BY 
    QuantidadeDeImoveis DESC;
"""

# sem index
# %sql DROP INDEX IF EXISTS indexAnfitriao;
# %sql EXPLAIN ANALYZE $sql_query
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
#  * postgresql://postgres:***@localhost/trabbd
# 20 rows affected.
# [('Sort  (cost=2711.60..2729.91 rows=7327 width=35) (actual time=198.588..200.254 rows=1751 loops=1)',),
#  ('  Sort Key: (count(p.id)) DESC',),
#  ('  Sort Method: quicksort  Memory: 186kB',),
#  ('  ->  HashAggregate  (cost=1966.49..2241.24 rows=7327 width=35) (actual time=185.536..197.095 rows=1751 loops=1)',),
#  ('        Group Key: u.id, l.cidade',),
#  ('        Filter: (count(p.id) >= 3)',),
#  ('        Rows Removed by Filter: 20229',),
#  ('        ->  Hash Join  (cost=664.06..1641.30 rows=32519 width=31) (actual time=27.277..144.385 rows=32519 loops=1)',),
#  ('              Hash Cond: (u.idlocalizacao = l.id)',),
#  ('              ->  Hash Join  (cost=658.55..1548.11 rows=32519 width=20) (actual time=27.076..104.513 rows=32519 loops=1)',),
#  ('                    Hash Cond: (p.idanfitriao = u.id)',),
#  ('                    ->  Seq Scan on propriedades p  (cost=0.00..804.19 rows=32519 width=8) (actual time=0.012..21.462 rows=32519 loops=1)',),
#  ('                    ->  Hash  (cost=383.80..383.80 rows=21980 width=16) (actual time=27.036..27.042 rows=21980 loops=1)',),
#  ('                          Buckets: 32768  Batches: 1  Memory Usage: 1323kB',),
#  ('                          ->  Seq Scan on usuarios u  (cost=0.00..383.80 rows=21980 width=16) (actual time=0.013..12.579 rows=21980 loops=1)',),
#  ('              ->  Hash  (cost=3.56..3.56 rows=156 width=19) (actual time=0.191..0.194 rows=156 loops=1)',),
#  ('                    Buckets: 1024  Batches: 1  Memory Usage: 16kB',),
#  ('                    ->  Seq Scan on localizacoes l  (cost=0.00..3.56 rows=156 width=19) (actual time=0.023..0.105 rows=156 loops=1)',),
#  ('Planning Time: 0.673 ms',),
#  ('Execution Time: 201.318 ms',)]

# %%
# com index
# %sql DROP INDEX IF EXISTS indexAnfitriao;
# %sql CREATE INDEX indexAnfitriao ON Propriedades (IDAnfitriao);
# %sql EXPLAIN ANALYZE $sql_query
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
#  * postgresql://postgres:***@localhost/trabbd
# Done.
#  * postgresql://postgres:***@localhost/trabbd
# 20 rows affected.
# [('Sort  (cost=2711.60..2729.91 rows=7327 width=35) (actual time=140.878..141.692 rows=1751 loops=1)',),
#  ('  Sort Key: (count(p.id)) DESC',),
#  ('  Sort Method: quicksort  Memory: 186kB',),
#  ('  ->  HashAggregate  (cost=1966.49..2241.24 rows=7327 width=35) (actual time=134.478..139.820 rows=1751 loops=1)',),
#  ('        Group Key: u.id, l.cidade',),
#  ('        Filter: (count(p.id) >= 3)',),
#  ('        Rows Removed by Filter: 20229',),
#  ('        ->  Hash Join  (cost=664.06..1641.30 rows=32519 width=31) (actual time=22.665..106.812 rows=32519 loops=1)',),
#  ('              Hash Cond: (u.idlocalizacao = l.id)',),
#  ('              ->  Hash Join  (cost=658.55..1548.11 rows=32519 width=20) (actual time=22.486..77.162 rows=32519 loops=1)',),
#  ('                    Hash Cond: (p.idanfitriao = u.id)',),
#  ('                    ->  Seq Scan on propriedades p  (cost=0.00..804.19 rows=32519 width=8) (actual time=0.014..15.518 rows=32519 loops=1)',),
#  ('                    ->  Hash  (cost=383.80..383.80 rows=21980 width=16) (actual time=22.454..22.456 rows=21980 loops=1)',),
#  ('                          Buckets: 32768  Batches: 1  Memory Usage: 1323kB',),
#  ('                          ->  Seq Scan on usuarios u  (cost=0.00..383.80 rows=21980 width=16) (actual time=0.019..10.615 rows=21980 loops=1)',),
#  ('              ->  Hash  (cost=3.56..3.56 rows=156 width=19) (actual time=0.173..0.175 rows=156 loops=1)',),
#  ('                    Buckets: 1024  Batches: 1  Memory Usage: 16kB',),
#  ('                    ->  Seq Scan on localizacoes l  (cost=0.00..3.56 rows=156 width=19) (actual time=0.024..0.094 rows=156 loops=1)',),
#  ('Planning Time: 5.568 ms',),
#  ('Execution Time: 142.506 ms',)]

# %%
# %sql $sql_query
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 1751 rows affected.
# [(91654021, 'Daniel', 'Rio de Janeiro', 104),
#  (1982737, 'Estadia', 'Rio de Janeiro', 78),
#  (14315601, 'Aroldo', 'Rio de Janeiro', 71),
#  (47584281, 'Renato', 'Rio de Janeiro', 68),
#  (6000862, 'Omar Do Rio', 'Rio de Janeiro', 66),
#  (371026651, 'Pineapples', 'Rio de Janeiro', 63),
#  (341887136, 'Tabas', 'Rio de Janeiro', 55),
#  (12909867, 'Giovanni', 'Rio de Janeiro', 47),
#  (8975746, 'Line Rio', 'Rio de Janeiro', 41),
#  (74463624, 'Mozart', 'Rio de Janeiro', 40),
#  (22805631, 'Latin Exclusive', 'Rio de Janeiro', 38),
#  (257601767, 'Raquel Grama', 'Rio de Janeiro', 38),
#  (13580277, 'Marcio', 'Rio de Janeiro', 37),
#  (2513825, 'Further', 'Rio de Janeiro', 36),
#  (49207110, 'Anfitriao Gente Boa', 'Rio de Janeiro', 35),
#  (532498, 'Luis', 'Rio de Janeiro', 34),
#  (14314998, 'Rio Unique', 'Rio de Janeiro', 34),
#  (1422607, 'Leo&Archanjo', 'Rio de Janeiro', 34),
#  (392083762, 'Oka', 'Rio de Janeiro', 33),
#  (60298129, 'Danide', 'Rio de Janeiro', 32),
#  (22713969, 'Maria', 'Rio de Janeiro', 31),
#  (4255118, 'Ricardo', 'Rio de Janeiro', 30),
#  (2919803, 'Felipe', 'Rio de Janeiro', 29),
#  (70646886, 'LuxoBrasil', 'Rio de Janeiro', 27),
#  (43898034, 'Giovani', 'Rio de Janeiro', 26),
#  (160833906, 'RioHost', 'Rio de Janeiro', 26),
#  (153721, 'Shushma', 'Rio de Janeiro', 26),
#  (10406037, 'Rio Houses', 'Rio de Janeiro', 25),
#  (6786750, 'Matteo', 'Rio de Janeiro', 25),
#  (74652696, 'Andreia', 'Rio de Janeiro', 24),
#  (30721359, 'I Live Global', 'Rio de Janeiro', 24),
#  (15900036, 'Israel Fagundes', 'Rio de Janeiro', 24),
#  (321818201, 'Maria Luisa', 'Rio de Janeiro', 24),
#  (30165706, 'Yes Temporada', 'Rio de Janeiro', 24),
#  (10541644, 'Virginia', 'Rio de Janeiro', 24),
#  (4005407, 'Erika', 'Rio de Janeiro', 24),
#  (4307081, 'Nereu A', 'Rio de Janeiro', 23),
#  (27229964, 'Beatriz', 'Rio de Janeiro', 23),
#  (8303861, 'Carlos Eduardo', 'Rio de Janeiro', 23),
#  (468723322, 'Villas In Brazil', 'Rio de Janeiro', 23),
#  (473492239, 'Mauricio', 'Rio de Janeiro', 23),
#  (292590334, 'Belsito Apartments', 'Rio de Janeiro', 23),
#  (149407, 'Ricardo', 'Rio de Janeiro', 22),
#  (319227148, 'Anfitrião Prime', 'Rio de Janeiro', 22),
#  (71645815, 'Adilson', 'Rio de Janeiro', 22),
#  (36744189, 'Monica', 'Rio de Janeiro', 22),
#  (310319158, 'Suellen', 'Rio de Janeiro', 21),
#  (26945147, 'Smartbnb', 'Rio de Janeiro', 21),
#  (15533343, 'Yuri', 'Rio de Janeiro', 21),
#  (92284964, 'BestStay', 'Rio de Janeiro', 21),
#  (167472593, 'Rio Stay Residence', 'Rio de Janeiro', 21),
#  (146347544, 'Frédéric', 'Rio de Janeiro', 21),
#  (16064460, 'Rômulo', 'Rio de Janeiro', 20),
#  (352008051, 'Marcolini', 'Rio de Janeiro', 20),
#  (318672692, 'Rafael', 'Rio de Janeiro', 20),
#  (463573876, 'Aran', 'Rio de Janeiro', 20),
#  (21365765, 'Unhotel', 'Rio de Janeiro', 20),
#  (249003418, 'Best', 'Rio de Janeiro', 20),
#  (113997985, 'HomeRio', 'Rio de Janeiro', 20),
#  (4438776, 'Elisabete', 'Rio de Janeiro', 19),
#  (823800, 'Rafaella', 'Rio de Janeiro', 19),
#  (446405145, 'Joel', 'Rio de Janeiro', 19),
#  (229244053, 'Leda', 'Rio de Janeiro', 19),
#  (137007102, 'FGibran', 'Rio de Janeiro', 18),
#  (10423223, 'Carlos Rio Reservas', 'Rio de Janeiro', 18),
#  (27994357, 'Henrique', 'Rio de Janeiro', 18),
#  (325713553, 'Filipe', 'Rio de Janeiro', 18),
#  (366913236, 'Daniel', 'Rio de Janeiro', 17),
#  (57671630, 'Leander', 'Rio de Janeiro', 17),
#  (213230578, 'Alexandre', 'Rio de Janeiro', 17),
#  (10507162, 'Mauricio', 'Rio de Janeiro', 17),
#  (21218739, 'Pedro', 'Rio de Janeiro', 16),
#  (9270905, 'Carlos', 'Rio de Janeiro', 16),
#  (459544, 'Temporada', 'Rio de Janeiro', 16),
#  (25067261, 'Emma', 'Rio de Janeiro', 16),
#  (408071697, 'Gabriela', 'Rio de Janeiro', 16),
#  (20370177, 'Sylvie', 'Rio de Janeiro', 15),
#  (13411812, 'Fernando', 'Rio de Janeiro', 15),
#  (2438594, 'WhereInRio', 'Rio de Janeiro', 15),
#  (35739862, 'Rodrigo', 'Rio de Janeiro', 14),
#  (13323106, 'Allan', 'Rio de Janeiro', 14),
#  (80329631, 'Neide', 'Rio de Janeiro', 14),
#  (14095160, 'Claudia', 'Rio de Janeiro', 14),
#  (238604267, 'Claudia', 'Rio de Janeiro', 14),
#  (192303063, 'Sivaldo', 'Rio de Janeiro', 14),
#  (5615480, 'Andrea', 'Rio de Janeiro', 14),
#  (102761308, 'Caio', 'Rio de Janeiro', 14),
#  (235177717, 'Claudio', 'Rio de Janeiro', 13),
#  (2312911, 'Elena E Sergio', 'Rio de Janeiro', 13),
#  (365760452, 'Rosi', 'Rio de Janeiro', 13),
#  (108643221, 'Celso Teixeira', 'Rio de Janeiro', 13),
#  (74338742, 'Atel', 'Rio de Janeiro', 13),
#  (467605641, 'Hostel Princess', 'Rio de Janeiro', 13),
#  (315740743, 'Maicon', 'Rio de Janeiro', 13),
#  (238544772, 'Cesar', 'Rio de Janeiro', 13),
#  (211001893, 'Fabio', 'Rio de Janeiro', 13),
#  (348293564, 'Juliana', 'Rio de Janeiro', 13),
#  (8669485, 'Adriano', 'Rio de Janeiro', 13),
#  (164822022, 'Temporada', 'Rio de Janeiro', 13),
#  (397106841, 'Jump In', 'Rio de Janeiro', 13),
#  (363700178, 'Ceres', 'Rio de Janeiro', 13),
#  (463844986, 'Lobie', 'Rio de Janeiro', 13),
#  (37238144, 'Rafaele Bispo', 'Rio de Janeiro', 13),
#  (401842074, 'Nayana', 'Rio de Janeiro', 13),
#  (8156211, 'Giovanna', 'Rio de Janeiro', 12),
#  (11782291, 'Lucas', 'Rio de Janeiro', 12),
#  (13664216, 'Maria Lucia', 'Rio de Janeiro', 12),
#  (13392098, 'Vinicio', 'Rio de Janeiro', 12),
#  (378545175, 'Jorge Luiz', 'Rio de Janeiro', 12),
#  (56259668, 'Sabrina Franklin', 'Rio de Janeiro', 12),
#  (148937129, 'Alessandra', 'Rio de Janeiro', 12),
#  (83831825, 'Mi Casa Su Casa', 'Rio de Janeiro', 12),
#  (5737780, 'Fabi', 'Rio de Janeiro', 12),
#  (21931975, 'Rio Temporada', 'Rio de Janeiro', 12),
#  (10467486, 'Carolina', 'Rio de Janeiro', 12),
#  (36258642, 'Patrick', 'Rio de Janeiro', 12),
#  (224192, 'David', 'Rio de Janeiro', 12),
#  (172345271, 'Monica', 'Rio de Janeiro', 12),
#  (66039372, 'Vitor & Carlos', 'Rio de Janeiro', 12),
#  (309591724, 'Renato', 'Rio de Janeiro', 12),
#  (429775424, 'Helô', 'Rio de Janeiro', 12),
#  (23369184, 'Juliana - Temporada Curta', 'Rio de Janeiro', 12),
#  (231818330, 'Matheus', 'Rio de Janeiro', 11),
#  (271367467, 'Anna', 'Rio de Janeiro', 11),
#  (84751001, 'Eveline', 'Rio de Janeiro', 11),
#  (90268480, 'Marcos', 'Rio de Janeiro', 11),
#  (272976656, 'Marcus Vinícius', 'Rio de Janeiro', 11),
#  (4581272, 'Diogo Rio Habitat', 'Rio de Janeiro', 11),
#  (526672837, 'Minha Casa De Temporada', 'Rio de Janeiro', 11),
#  (216622191, 'Marilene', 'Rio de Janeiro', 11),
#  (29963280, 'Paulo', 'Rio de Janeiro', 11),
#  (523251, 'Humberto', 'Rio de Janeiro', 11),
#  (347487511, 'Rodrigo', 'Rio de Janeiro', 11),
#  (489381613, 'Marcos Rodrigo', 'Rio de Janeiro', 11),
#  (29475411, 'Bruno & Ricardo', 'Rio de Janeiro', 11),
#  (167997008, 'Monica', 'Rio de Janeiro', 11),
#  (112504243, 'Sonia', 'Rio de Janeiro', 11),
#  (55128713, 'Normando', 'Rio de Janeiro', 11),
#  (894049, 'Janara', 'Rio de Janeiro', 11),
#  (4420701, 'Gustavo', 'Rio de Janeiro', 10),
#  (15275005, 'Jonas', 'Rio de Janeiro', 10),
#  (446253282, 'Flavia', 'Rio de Janeiro', 10),
#  (11933341, 'Petruza', 'Rio de Janeiro', 10),
#  (202660425, 'Leila', 'Rio de Janeiro', 10),
#  (98289727, 'Mm Aluguel Por Temporada', 'Rio de Janeiro', 10),
#  (277358509, 'Flat Residence', 'Rio de Janeiro', 10),
#  (8364280, 'Jan', 'Rio de Janeiro', 10),
#  (12902528, 'Lilien', 'Rio de Janeiro', 10),
#  (490978942, 'Hans', 'Rio de Janeiro', 10),
#  (39817386, 'Reserve', 'Rio de Janeiro', 10),
#  (9226189, 'Débora', 'Rio de Janeiro', 10),
#  (4376064, 'Anfitriões', 'Rio de Janeiro', 10),
#  (3018529, 'Marcia', 'Rio de Janeiro', 10),
#  (535841659, 'Hostel', 'Rio de Janeiro', 10),
#  (7955669, 'Katia Valeria', 'Rio de Janeiro', 10),
#  (23488225, 'Max', 'Rio de Janeiro', 10),
#  (358323282, 'Rafael', 'Rio de Janeiro', 10),
#  (13359269, 'Antonio', 'Rio de Janeiro', 10),
#  (8000736, 'Andrade', 'Rio de Janeiro', 10),
#  (31226043, 'Alan', 'Rio de Janeiro', 10),
#  (131669310, 'Bruno & Marcos', 'Rio de Janeiro', 10),
#  (177786203, 'Jocelyn', 'Rio de Janeiro', 10),
#  (23218244, 'Anna', 'Rio de Janeiro', 10),
#  (78598801, 'Cláudia', 'Rio de Janeiro', 9),
#  (26005554, 'Serginho Rauen VizooBuzios', 'Rio de Janeiro', 9),
#  (11323527, 'David', 'Rio de Janeiro', 9),
#  (467812039, 'Agnes', 'Rio de Janeiro', 9),
#  (201418761, 'Carlos', 'Rio de Janeiro', 9),
#  (337762439, 'Thiago', 'Rio de Janeiro', 9),
#  (26748682, 'Rose', 'Rio de Janeiro', 9),
#  (32168832, 'Marcus', 'Rio de Janeiro', 9),
#  (39135642, 'Juliana', 'Rio de Janeiro', 9),
#  (401229484, 'Manuella', 'Rio de Janeiro', 9),
#  (11070008, 'BlissRio', 'Rio de Janeiro', 9),
#  (485252166, 'Erivan', 'Rio de Janeiro', 9),
#  (11504031, 'Valdene', 'Rio de Janeiro', 9),
#  (152217261, 'Taina', 'Rio de Janeiro', 9),
#  (492291708, 'Jacqueline', 'Rio de Janeiro', 9),
#  (77709888, 'Vanessa', 'Rio de Janeiro', 9),
#  (1537641, 'Gilles', 'Rio de Janeiro', 9),
#  (115138742, 'Karina', 'Rio de Janeiro', 9),
#  (272752257, 'Felipe', 'Rio de Janeiro', 9),
#  (115075111, 'Lis', 'Rio de Janeiro', 9),
#  (47248185, 'Maria Luiza', 'Rio de Janeiro', 9),
#  (70933, 'Goitaca', 'Rio de Janeiro', 9),
#  (232555342, 'Regina', 'Rio de Janeiro', 9),
#  (320966647, 'Petruza', 'Rio de Janeiro', 9),
#  (46664224, 'Rafael', 'Rio de Janeiro', 9),
#  (351259985, 'Carolina', 'Rio de Janeiro', 9),
#  (6217672, 'Fernando', 'Rio de Janeiro', 9),
#  (13635061, 'Adriana', 'Rio de Janeiro', 9),
#  (534675, 'Junior', 'Rio de Janeiro', 9),
#  (454830327, 'Clara', 'Rio de Janeiro', 9),
#  (387761453, 'Rafael', 'Rio de Janeiro', 8),
#  (228348887, 'Hélio', 'Rio de Janeiro', 8),
#  (513685, 'Carlos', 'Rio de Janeiro', 8),
#  (48720390, 'Fariza', 'Rio de Janeiro', 8),
#  (10607843, 'Rio Hosting', 'Rio de Janeiro', 8),
#  (13753183, 'Raíssa', 'Rio de Janeiro', 8),
#  (320261036, 'Jefferson', 'Rio de Janeiro', 8),
#  (4832097, 'Celi', 'Rio de Janeiro', 8),
#  (11607286, 'Josana', 'Rio de Janeiro', 8),
#  (325572562, 'Sonia Iris', 'Rio de Janeiro', 8),
#  (8477603, 'Pamela', 'Rio de Janeiro', 8),
#  (137109572, 'Mango Tree Ipanema', 'Rio de Janeiro', 8),
#  (406555768, 'Maria Helena', 'Rio de Janeiro', 8),
#  (511384819, 'João Ricardo', 'Rio de Janeiro', 8),
#  (302960741, 'Solar', 'Rio de Janeiro', 8),
#  (80338139, 'Cláudia', 'Rio de Janeiro', 8),
#  (499353982, 'Comercial', 'Rio de Janeiro', 8),
#  (13949537, 'Alexander', 'Rio de Janeiro', 8),
#  (415432275, 'Sunset Rio', 'Rio de Janeiro', 8),
#  (26414324, 'Alire Lima', 'Rio de Janeiro', 8),
#  (3665789, 'Beta Gatti', 'Rio de Janeiro', 8),
#  (79151243, 'Breno', 'Rio de Janeiro', 8),
#  (4036979, 'Daniela', 'Rio de Janeiro', 8),
#  (473819006, 'Mara', 'Rio de Janeiro', 8),
#  (16017168, 'Elza', 'Rio de Janeiro', 8),
#  (64294308, 'Terezinha', 'Rio de Janeiro', 8),
#  (50893268, 'Adriana', 'Rio de Janeiro', 8),
#  (429604997, 'Bárbara', 'Rio de Janeiro', 8),
#  (68850265, 'Bette', 'Rio de Janeiro', 8),
#  (22240461, 'Tatiana', 'Rio de Janeiro', 8),
#  (229472947, 'Valeska', 'Rio de Janeiro', 8),
#  (25130130, 'Fabio', 'Rio de Janeiro', 8),
#  (425294959, 'Rami', 'Rio de Janeiro', 8),
#  (36289458, 'Maria', 'Rio de Janeiro', 8),
#  (6687502, 'Casa Babilônia', 'Rio de Janeiro', 8),
#  (224799115, 'Isabela', 'Rio de Janeiro', 8),
#  (4284876, 'Silvia', 'Rio de Janeiro', 8),
#  (67587712, 'Gabriel', 'Rio de Janeiro', 8),
#  (406354831, 'Sheila', 'Rio de Janeiro', 8),
#  (792218, 'Levy', 'Rio de Janeiro', 8),
#  (1675920, 'Dacia', 'Rio de Janeiro', 8),
#  (106863172, 'Geane', 'Rio de Janeiro', 8),
#  (64275672, 'Adam', 'Rio de Janeiro', 8),
#  (601323, 'Laurent', 'Rio de Janeiro', 7),
#  (497786, 'Butterfly Vanazul', 'Rio de Janeiro', 7),
#  (63099507, 'Fabiani', 'Rio de Janeiro', 7),
#  (10823485, 'Vania', 'Rio de Janeiro', 7),
#  (32416144, 'Alexandre', 'Rio de Janeiro', 7),
#  (70426798, 'Márcia', 'Rio de Janeiro', 7),
#  (3802101, 'Katya', 'Rio de Janeiro', 7),
#  (160469308, 'Ursula', 'Rio de Janeiro', 7),
#  (330224882, 'Josue', 'Rio de Janeiro', 7),
#  (156636821, 'Thaissa', 'Rio de Janeiro', 7),
#  (95117133, 'Raissa', 'Rio de Janeiro', 7),
#  (10486509, 'Arno & Igor', 'Rio de Janeiro', 7),
#  (635510, 'Gilberto', 'Rio de Janeiro', 7),
#  (544744044, 'A2', 'Rio de Janeiro', 7),
#  (172482654, 'Evilene', 'Rio de Janeiro', 7),
#  (10564794, 'Eduardo', 'Rio de Janeiro', 7),
#  (2537111, 'Barbara', 'Rio de Janeiro', 7),
#  (203022450, 'Ronaldo', 'Rio de Janeiro', 7),
#  (10796926, 'Sugar Loft Apartments', 'Rio de Janeiro', 7),
#  (24521701, 'Fatima', 'Rio de Janeiro', 7),
#  (87767987, 'Giselle', 'Rio de Janeiro', 7),
#  (431412286, 'Carlos Henrique', 'Rio de Janeiro', 7),
#  (13272749, 'Sonia', 'Rio de Janeiro', 7),
#  (58769289, 'Monica', 'Rio de Janeiro', 7),
#  (175671577, 'Top House', 'Rio de Janeiro', 7),
#  (6005451, 'Tereza', 'Rio de Janeiro', 7),
#  (335170968, 'Christine', 'Rio de Janeiro', 7),
#  (206038342, 'Cláudia', 'Rio de Janeiro', 7),
#  (15221271, 'Robson', 'Rio de Janeiro', 7),
#  (11386725, 'Carolina', 'Rio de Janeiro', 7),
#  (500936420, 'Fernanda', 'Rio de Janeiro', 7),
#  (9967131, 'Aline', 'Rio de Janeiro', 7),
#  (46226066, 'Alvar Mario', 'Rio de Janeiro', 7),
#  (42685021, 'Roberto', 'Rio de Janeiro', 7),
#  (15925374, 'Luiz Renato', 'Rio de Janeiro', 7),
#  (67850207, 'Tupiniquim Hostel', 'Rio de Janeiro', 7),
#  (78817280, 'Wagner', 'Rio de Janeiro', 7),
#  (171869673, 'Denise', 'Rio de Janeiro', 7),
#  (67255068, 'Home', 'Rio de Janeiro', 7),
#  (68163291, 'Valder', 'Rio de Janeiro', 7),
#  (248739218, 'Maria', 'Rio de Janeiro', 7),
#  (228237182, 'Eliane', 'Rio de Janeiro', 7),
#  (48024, 'Gustavo', 'Rio de Janeiro', 7),
#  (477415028, 'Rio 222', 'Rio de Janeiro', 7),
#  (62525920, 'Adriana', 'Rio de Janeiro', 7),
#  (426256392, 'Ipanema Club', 'Rio de Janeiro', 7),
#  (52557989, 'Alexandre', 'Rio de Janeiro', 7),
#  (4168266, 'CabanaCopa', 'Rio de Janeiro', 7),
#  (491350351, 'Fernanda', 'Rio de Janeiro', 7),
#  (17175278, 'Elcio', 'Rio de Janeiro', 7),
#  (13952932, 'Fabiana', 'Rio de Janeiro', 7),
#  (44729495, 'Juliana', 'Rio de Janeiro', 7),
#  (652627, 'Ana', 'Rio de Janeiro', 7),
#  (130642381, 'Mahnai', 'Rio de Janeiro', 7),
#  (17325065, 'Artur', 'Rio de Janeiro', 7),
#  (458980426, 'Eduardo', 'Rio de Janeiro', 7),
#  (9465134, 'Aline', 'Rio de Janeiro', 7),
#  (4232062, 'Meg', 'Rio de Janeiro', 7),
#  (152441811, 'Thiago', 'Rio de Janeiro', 7),
#  (302209040, 'Vinicius', 'Rio de Janeiro', 7),
#  (13895463, 'Gabi', 'Rio de Janeiro', 7),
#  (9387742, 'Leandra', 'Rio de Janeiro', 7),
#  (221597210, 'Marcilene', 'Rio de Janeiro', 7),
#  (111551444, 'Fátima', 'Rio de Janeiro', 7),
#  (5838889, 'Marie', 'Rio de Janeiro', 7),
#  (1429181, 'Samuel', 'Rio de Janeiro', 7),
#  (40151333, 'Rita', 'Rio de Janeiro', 7),
#  (174303208, 'Àlan', 'Rio de Janeiro', 7),
#  (11739, 'Eric', 'Rio de Janeiro', 7),
#  (158098971, 'Myrian', 'Rio de Janeiro', 6),
#  (346655886, 'Marcus André', 'Rio de Janeiro', 6),
#  (27531233, 'Tiago', 'Rio de Janeiro', 6),
#  (14232658, 'Paulo', 'Rio de Janeiro', 6),
#  (316921706, 'Paulo', 'Rio de Janeiro', 6),
#  (380142448, 'Alex', 'Rio de Janeiro', 6),
#  (346082128, 'SNS Patrimonial E Serviços Ltda', 'Rio de Janeiro', 6),
#  (536600082, 'Laris', 'Rio de Janeiro', 6),
#  (52771823, 'Sheila', 'Rio de Janeiro', 6),
#  (423392969, 'Thiago', 'Rio de Janeiro', 6),
#  (76210086, 'Mc Flats', 'Rio de Janeiro', 6),
#  (479312966, 'Emilio', 'Rio de Janeiro', 6),
#  (51227019, 'Pedro', 'Rio de Janeiro', 6),
#  (113346982, 'Stefan', 'Rio de Janeiro', 6),
#  (442620033, 'Lidia Nayara', 'Rio de Janeiro', 6),
#  (109885396, 'Sebastião', 'Rio de Janeiro', 6),
#  (1577817, 'Olivier', 'Rio de Janeiro', 6),
#  (296430347, 'Rodrigo', 'Rio de Janeiro', 6),
#  (16545585, 'Celia', 'Rio de Janeiro', 6),
#  (517386494, 'Beach House Gigóia', 'Rio de Janeiro', 6),
#  (63954449, 'Jorge', 'Rio de Janeiro', 6),
#  (122261758, 'Skala', 'Rio de Janeiro', 6),
#  (30975221, 'Rio Guests', 'Rio de Janeiro', 6),
#  (23543878, 'Paulo', 'Rio de Janeiro', 6),
#  (62913860, 'Rodolfo', 'Rio de Janeiro', 6),
#  (222108450, 'Tatiana', 'Rio de Janeiro', 6),
#  (30717384, 'Isabela', 'Rio de Janeiro', 6),
#  (85897939, 'Flavia Prista', 'Rio de Janeiro', 6),
#  (36981403, 'Cristina', 'Rio de Janeiro', 6),
#  (53461053, 'Ana Paula', 'Rio de Janeiro', 6),
#  (5228078, 'Marcelo', 'Rio de Janeiro', 6),
#  (5244204, 'Milla', 'Rio de Janeiro', 6),
#  (327244298, 'Daniel', 'Rio de Janeiro', 6),
#  (5532376, 'Andre', 'Rio de Janeiro', 6),
#  (156237325, 'Thiago', 'Rio de Janeiro', 6),
#  (69922816, 'Arnaud', 'Rio de Janeiro', 6),
#  (352599409, 'Best In Rio Stay Convention Suites', 'Rio de Janeiro', 6),
#  (11389355, 'Leticia', 'Rio de Janeiro', 6),
#  (210041079, 'Goya', 'Rio de Janeiro', 6),
#  (116235207, 'Paulo', 'Rio de Janeiro', 6),
#  (413577, 'Bernardo', 'Rio de Janeiro', 6),
#  (2208473, 'Walbenir', 'Rio de Janeiro', 6),
#  (271615742, 'Rita', 'Rio de Janeiro', 6),
#  (11411976, 'Paula', 'Rio de Janeiro', 6),
#  (193205371, 'Victor', 'Rio de Janeiro', 6),
#  (270247199, 'Aqui Eu Rio', 'Rio de Janeiro', 6),
#  (5942159, 'Marco', 'Rio de Janeiro', 6),
#  (13832827, 'Bernardo', 'Rio de Janeiro', 6),
#  (10640170, 'Ana', 'Rio de Janeiro', 6),
#  (110636072, 'Rosilene Schneider', 'Rio de Janeiro', 6),
#  (34459302, 'Gisele', 'Rio de Janeiro', 6),
#  (39695742, 'Alberto', 'Rio de Janeiro', 6),
#  (235670926, 'Diogo', 'Rio de Janeiro', 6),
#  (130328815, 'Sonia E Gabriela', 'Rio de Janeiro', 6),
#  (483447030, 'Ruy', 'Rio de Janeiro', 6),
#  (3746246, 'Ghizlane', 'Rio de Janeiro', 6),
#  (43480511, 'Igor', 'Rio de Janeiro', 6),
#  (8782308, 'Julia Zany', 'Rio de Janeiro', 6),
#  (14743853, 'Carlos', 'Rio de Janeiro', 6),
#  (1168587, 'Patricia', 'Rio de Janeiro', 6),
#  (330417921, 'Jeane Ormond', 'Rio de Janeiro', 6),
#  (9739433, 'Vivian', 'Rio de Janeiro', 6),
#  (15758557, 'Francisco', 'Rio de Janeiro', 6),
#  (61714845, 'Paulo', 'Rio de Janeiro', 6),
#  (390140856, 'Heron', 'Rio de Janeiro', 6),
#  (431676014, 'Sabrina', 'Rio de Janeiro', 6),
#  (4106244, 'Guilherme', 'Rio de Janeiro', 6),
#  (2903813, 'Lucia', 'Rio de Janeiro', 6),
#  (36640543, 'Artur', 'Rio de Janeiro', 6),
#  (15175491, 'Pricila', 'Rio de Janeiro', 6),
#  (92034724, 'Adriana', 'Rio de Janeiro', 6),
#  (13501097, 'Enzo', 'Rio de Janeiro', 6),
#  (242968329, 'Vinicius', 'Rio de Janeiro', 6),
#  (135845476, 'Casa Do Mar', 'Rio de Janeiro', 6),
#  (303124704, 'Marco', 'Rio de Janeiro', 6),
#  (3308731, 'Stay', 'Rio de Janeiro', 6),
#  (29593595, 'Sweet Homes Rio', 'Rio de Janeiro', 6),
#  (56179426, 'Pedro', 'Rio de Janeiro', 6),
#  (468900451, 'Simone', 'Rio de Janeiro', 6),
#  (530231, 'Yaya', 'Rio de Janeiro', 6),
#  (6668899, 'Paulo Marcos', 'Rio de Janeiro', 6),
#  (477274210, 'Cadê Teresa', 'Rio de Janeiro', 6),
#  (475340957, 'Adv', 'Rio de Janeiro', 6),
#  (302575174, 'Helmar Oliveira', 'Rio de Janeiro', 6),
#  (5862587, 'Paula', 'Rio de Janeiro', 6),
#  (14279272, 'Flavio', 'Rio de Janeiro', 6),
#  (153667273, 'Fernando', 'Rio de Janeiro', 6),
#  (369641212, 'Solano Rodrigo', 'Rio de Janeiro', 6),
#  (78713589, 'Augusto', 'Rio de Janeiro', 6),
#  (158742579, 'Eberson', 'Rio de Janeiro', 6),
#  (380418292, 'Bruno', 'Rio de Janeiro', 6),
#  (2125175, 'Eliete', 'Rio de Janeiro', 6),
#  (170522649, 'João Pedro', 'Rio de Janeiro', 6),
#  (445730956, 'Apart-Hotel Convention Rio Stay', 'Rio de Janeiro', 6),
#  (111555164, 'Juliana Bento', 'Rio de Janeiro', 6),
#  (59519391, 'Márcio', 'Rio de Janeiro', 6),
#  (1796794, 'Yara', 'Rio de Janeiro', 6),
#  (27149197, 'Maria Luisa', 'Rio de Janeiro', 6),
#  (514115445, 'Juan Angel', 'Rio de Janeiro', 6),
#  (5573690, 'Luciana', 'Rio de Janeiro', 6),
#  (523903815, 'Reinaldo', 'Rio de Janeiro', 6),
#  (14015723, 'Geraldo & Simone', 'Rio de Janeiro', 6),
#  (231159376, 'Ursula', 'Rio de Janeiro', 6),
#  (980805, 'Henrique', 'Rio de Janeiro', 6),
#  (318163118, 'Renata', 'Rio de Janeiro', 6),
#  (32429803, 'Milton', 'Rio de Janeiro', 6),
#  (3890087, 'Peter', 'Rio de Janeiro', 6),
#  (286053300, 'Natasha', 'Rio de Janeiro', 6),
#  (54899116, 'Rudá', 'Rio de Janeiro', 6),
#  (58857593, 'Luiza', 'Rio de Janeiro', 6),
#  (496656, 'Marcia  Longras', 'Rio de Janeiro', 6),
#  (470173166, 'Marco', 'Rio de Janeiro', 6),
#  (56337810, 'Socorro Costa', 'Rio de Janeiro', 6),
#  (155819967, 'Carolina', 'Rio de Janeiro', 6),
#  (10214925, 'Onayr', 'Rio de Janeiro', 5),
#  (404458319, 'William', 'Rio de Janeiro', 5),
#  (299563308, 'Stefany', 'Rio de Janeiro', 5),
#  (421420448, 'Vinicius', 'Rio de Janeiro', 5),
#  (12180348, 'Diogo', 'Rio de Janeiro', 5),
#  (398674687, 'Taisa E Vitor', 'Rio de Janeiro', 5),
#  (386204706, 'Paulo', 'Rio de Janeiro', 5),
#  (22579735, 'Renata', 'Rio de Janeiro', 5),
#  (531465580, 'Yron', 'Rio de Janeiro', 5),
#  (4873555, 'Pedro', 'Rio de Janeiro', 5),
#  (422476687, 'Rafael', 'Rio de Janeiro', 5),
#  (4622315, 'Rafael', 'Rio de Janeiro', 5),
#  (4884558, 'Anselmo', 'Rio de Janeiro', 5),
#  (2915201, 'Jules Rimet', 'Rio de Janeiro', 5),
#  (234275790, 'Forest Club', 'Rio de Janeiro', 5),
#  (475501342, 'Victor', 'Rio de Janeiro', 5),
#  (167035172, 'Teresa', 'Rio de Janeiro', 5),
#  (436525910, 'Luiz Henrique', 'Rio de Janeiro', 5),
#  (543097420, 'Roxana', 'Rio de Janeiro', 5),
#  (86774316, 'Rogerio', 'Rio de Janeiro', 5),
#  (25644407, 'Vera', 'Rio de Janeiro', 5),
#  (113889162, 'Thais', 'Rio de Janeiro', 5),
#  (53588365, 'Maurício', 'Rio de Janeiro', 5),
#  (90259160, 'Anna Carolina', 'Rio de Janeiro', 5),
#  (81970516, 'Fraser', 'Rio de Janeiro', 5),
#  (1381764, 'Pineapples', 'Rio de Janeiro', 5),
#  (43038549, 'Eduardo', 'Rio de Janeiro', 5),
#  (77023853, 'Marcello', 'Rio de Janeiro', 5),
#  (112871092, 'Karolla', 'Rio de Janeiro', 5),
#  (197242788, 'Michael', 'Rio de Janeiro', 5),
#  (160620333, 'Paulo', 'Rio de Janeiro', 5),
#  (15671309, 'Camila', 'Rio de Janeiro', 5),
#  (25571291, 'Ricardo', 'Rio de Janeiro', 5),
#  (240610100, 'Jandira', 'Rio de Janeiro', 5),
#  (6080771, 'Danielle', 'Rio de Janeiro', 5),
#  (434348285, 'Thiago', 'Rio de Janeiro', 5),
#  (128400147, 'Debora', 'Rio de Janeiro', 5),
#  (404052111, 'Ana', 'Rio de Janeiro', 5),
#  (9449475, 'Maria', 'Rio de Janeiro', 5),
#  (59013736, 'Marcio', 'Rio de Janeiro', 5),
#  (349897129, 'Nelia Pereira', 'Rio de Janeiro', 5),
#  (17244708, 'Eraldo', 'Rio de Janeiro', 5),
#  (372578235, 'Joao Pedro', 'Rio de Janeiro', 5),
#  (104742647, 'Izabella', 'Rio de Janeiro', 5),
#  (476677023, 'Reynaldo', 'Rio de Janeiro', 5),
#  (37776540, 'Mariana', 'Rio de Janeiro', 5),
#  (9311462, 'Tereza', 'Rio de Janeiro', 5),
#  (15013867, 'Fernanda', 'Rio de Janeiro', 5),
#  (5165851, 'Manfred', 'Rio de Janeiro', 5),
#  (62031792, 'Rodrigo', 'Rio de Janeiro', 5),
#  (38567806, 'Felipe', 'Rio de Janeiro', 5),
#  (6213964, 'Efigenia', 'Rio de Janeiro', 5),
#  (156250325, 'Glasdow', 'Rio de Janeiro', 5),
#  (84048033, 'Frederic', 'Rio de Janeiro', 5),
#  (42234930, 'Susana', 'Rio de Janeiro', 5),
#  (96474135, 'Alzerina', 'Rio de Janeiro', 5),
#  (106411720, 'Marcelo', 'Rio de Janeiro', 5),
#  (490346774, 'Helena', 'Rio de Janeiro', 5),
#  (13596474, 'Luisa', 'Rio de Janeiro', 5),
#  (66804622, 'Ana Paula', 'Rio de Janeiro', 5),
#  (15560428, 'Aline E Isabelle', 'Rio de Janeiro', 5),
#  (323842917, 'HAna Hostel Albergues E', 'Rio de Janeiro', 5),
#  (10344782, 'Ney', 'Rio de Janeiro', 5),
#  (18117704, 'Rafael', 'Rio de Janeiro', 5),
#  (242965430, 'Anderson', 'Rio de Janeiro', 5),
#  (103275390, 'Anderson', 'Rio de Janeiro', 5),
#  (76356053, 'Douglas', 'Rio de Janeiro', 5),
#  (493169411, 'Daiana', 'Rio de Janeiro', 5),
#  (167576710, 'Marco', 'Rio de Janeiro', 5),
#  (37427403, 'Arthur', 'Rio de Janeiro', 5),
#  (162022411, 'Patrick', 'Rio de Janeiro', 5),
#  (168203934, 'Flavia', 'Rio de Janeiro', 5),
#  (76710208, 'Alessandra', 'Rio de Janeiro', 5),
#  (105113529, 'Urca Hotel', 'Rio de Janeiro', 5),
#  (21743110, 'Kamila', 'Rio de Janeiro', 5),
#  (27909203, 'Sandra', 'Rio de Janeiro', 5),
#  (12938211, 'Luxury Worldwide', 'Rio de Janeiro', 5),
#  (38683129, 'Rosario', 'Rio de Janeiro', 5),
#  (55248222, 'Filipi E Jessica', 'Rio de Janeiro', 5),
#  (383249441, 'Sergio', 'Rio de Janeiro', 5),
#  (490306038, 'Pedro', 'Rio de Janeiro', 5),
#  (163618992, 'HomeStays', 'Rio de Janeiro', 5),
#  (11107884, 'Tatiana', 'Rio de Janeiro', 5),
#  (248462674, 'Arthur', 'Rio de Janeiro', 5),
#  (135031039, 'Maria', 'Rio de Janeiro', 5),
#  (473432596, 'Marcelo Lourenço', 'Rio de Janeiro', 5),
#  (53918534, 'Quiá', 'Rio de Janeiro', 5),
#  (27709253, 'Eliane', 'Rio de Janeiro', 5),
#  (32987257, 'Angela', 'Rio de Janeiro', 5),
#  (62933995, 'Izilda', 'Rio de Janeiro', 5),
#  (16992056, 'Irineu', 'Rio de Janeiro', 5),
#  (145176530, 'Marco', 'Rio de Janeiro', 5),
#  (66649352, 'Luana Capaverde', 'Rio de Janeiro', 5),
#  (200621357, 'Marcela', 'Rio de Janeiro', 5),
#  (95754481, 'Diogo', 'Rio de Janeiro', 5),
#  (22296412, 'J Renato', 'Rio de Janeiro', 5),
#  (24859801, 'Daniela', 'Rio de Janeiro', 5),
#  (406013064, 'Marlen', 'Rio de Janeiro', 5),
#  (260872948, 'Bárbara', 'Rio de Janeiro', 5),
#  (12498767, 'CrisSKoester', 'Rio de Janeiro', 5),
#  (9235956, 'Lucia', 'Rio de Janeiro', 5),
#  (79244301, 'Fabiano', 'Rio de Janeiro', 5),
#  (141866453, 'Vanessa', 'Rio de Janeiro', 5),
#  (41846354, 'Reynaldo', 'Rio de Janeiro', 5),
#  (66513543, 'Patricia', 'Rio de Janeiro', 5),
#  (221385660, 'Roberto', 'Rio de Janeiro', 5),
#  (477833142, 'André', 'Rio de Janeiro', 5),
#  (16445274, 'Paulo', 'Rio de Janeiro', 5),
#  (11647707, 'Rose', 'Rio de Janeiro', 5),
#  (378854391, 'Stacy E Bueno', 'Rio de Janeiro', 5),
#  (10548523, 'Antonio', 'Rio de Janeiro', 5),
#  (163240238, 'Amanda', 'Rio de Janeiro', 5),
#  (23654943, 'Luciana', 'Rio de Janeiro', 5),
#  (499912236, 'Tiago', 'Rio de Janeiro', 5),
#  (150144948, 'Renan', 'Rio de Janeiro', 5),
#  (341798459, 'Rosemary', 'Rio de Janeiro', 5),
#  (336908, 'Alexandre', 'Rio de Janeiro', 5),
#  (297672983, 'Hotel', 'Rio de Janeiro', 5),
#  (219674326, 'Natanna', 'Rio de Janeiro', 5),
#  (10464160, 'Mireille', 'Rio de Janeiro', 5),
#  (270380307, 'Priscilla', 'Rio de Janeiro', 5),
#  (494512225, 'João Victor', 'Rio de Janeiro', 5),
#  (158933362, 'Cássia Ou Arlindo', 'Rio de Janeiro', 5),
#  (11133417, 'Suzana', 'Rio de Janeiro', 5),
#  (278641760, 'Alberto', 'Rio de Janeiro', 5),
#  (240364027, 'Debora', 'Rio de Janeiro', 5),
#  (16613801, 'Ale', 'Rio de Janeiro', 5),
#  (83354976, 'Adriano', 'Rio de Janeiro', 5),
#  (2655983, 'Claudia', 'Rio de Janeiro', 5),
#  (475193730, 'Carolinna', 'Rio de Janeiro', 5),
#  (72593893, 'Mariana', 'Rio de Janeiro', 5),
#  (549301884, 'Jully', 'Rio de Janeiro', 5),
#  (208632582, 'Francisco', 'Rio de Janeiro', 5),
#  (13639219, 'Alex', 'Rio de Janeiro', 5),
#  (16120213, 'Roberta', 'Rio de Janeiro', 5),
#  (2538304, 'Sonia', 'Rio de Janeiro', 5),
#  (83729062, 'William', 'Rio de Janeiro', 5),
#  (178877979, 'Romario', 'Rio de Janeiro', 5),
#  (89566669, 'Helena', 'Rio de Janeiro', 5),
#  (145036386, 'Amanda', 'Rio de Janeiro', 5),
#  (396858614, 'Joice', 'Rio de Janeiro', 5),
#  (506564579, 'Simone', 'Rio de Janeiro', 5),
#  (474837290, 'Joel', 'Rio de Janeiro', 5),
#  (27377433, 'Celso', 'Rio de Janeiro', 5),
#  (12683327, 'Ana Paula', 'Rio de Janeiro', 5),
#  (17070351, 'Carlos', 'Rio de Janeiro', 5),
#  (5547261, 'Família Rotti', 'Rio de Janeiro', 5),
#  (24766519, 'Renato', 'Rio de Janeiro', 5),
#  (233593841, 'Alice', 'Rio de Janeiro', 5),
#  (84092121, 'Rosana', 'Rio de Janeiro', 5),
#  (470263635, 'Larissa', 'Rio de Janeiro', 5),
#  (10553239, 'Cris', 'Rio de Janeiro', 5),
#  (4947020, 'Laura', 'Rio de Janeiro', 5),
#  (137505233, 'Michele', 'Rio de Janeiro', 5),
#  (484129194, 'Clara', 'Rio de Janeiro', 5),
#  (506229505, 'Alan', 'Rio de Janeiro', 5),
#  (412334312, 'Raul', 'Rio de Janeiro', 5),
#  (323602412, 'Fernanda', 'Rio de Janeiro', 5),
#  (76283151, 'Ana Paula', 'Rio de Janeiro', 5),
#  (474500684, 'Davy', 'Rio de Janeiro', 5),
#  (102322330, 'Jeanne', 'Rio de Janeiro', 5),
#  (85170948, 'Dayana', 'Rio de Janeiro', 5),
#  (5967632, 'Doni', 'Rio de Janeiro', 5),
#  (443318137, 'Vitor', 'Rio de Janeiro', 5),
#  (4232997, 'Gabriel', 'Rio de Janeiro', 5),
#  (6422051, 'CrisTemporada', 'Rio de Janeiro', 5),
#  (10546234, 'Patricia', 'Rio de Janeiro', 5),
#  (288667254, 'Cintia', 'Rio de Janeiro', 5),
#  (434570599, 'Rogerio', 'Rio de Janeiro', 5),
#  (116135653, 'Hugo', 'Rio de Janeiro', 5),
#  (54931890, 'Silvia', 'Rio de Janeiro', 5),
#  (494160174, 'Brunno Gabriel', 'Rio de Janeiro', 5),
#  (13680324, 'Lucila', 'Rio de Janeiro', 5),
#  (487332542, 'Elizabeth', 'Rio de Janeiro', 5),
#  (488619544, 'Catia Maria', 'Rio de Janeiro', 5),
#  (494964, 'Beatriz', 'Rio de Janeiro', 5),
#  (319672, 'Valeria', 'Rio de Janeiro', 5),
#  (432143221, 'Marcus Vinicius', 'Rio de Janeiro', 5),
#  (171632668, 'Andre Luiz', 'Rio de Janeiro', 5),
#  (25341342, 'Isabella', 'Rio de Janeiro', 5),
#  (3962758, 'Thiago Luiz', 'Rio de Janeiro', 5),
#  (490744881, 'Leonaldo', 'Rio de Janeiro', 5),
#  (4168313, 'Matthieu', 'Rio de Janeiro', 5),
#  (456191779, 'Rildo', 'Rio de Janeiro', 5),
#  (406989, 'Casa 48 Guesthouse', 'Rio de Janeiro', 5),
#  (260411129, 'Monica', 'Rio de Janeiro', 5),
#  (1648634, 'Jose', 'Rio de Janeiro', 5),
#  (474387007, 'Ricardo', 'Rio de Janeiro', 5),
#  (225797957, 'Daniela', 'Rio de Janeiro', 5),
#  (166827375, 'More Só', 'Rio de Janeiro', 5),
#  (54233024, 'Laurent', 'Rio de Janeiro', 5),
#  (72551339, 'Lilia', 'Rio de Janeiro', 5),
#  (155118499, 'Phellipe', 'Rio de Janeiro', 5),
#  (421876226, 'Natália', 'Rio de Janeiro', 5),
#  (34316296, 'Daniela', 'Rio de Janeiro', 5),
#  (84553413, 'Karina', 'Rio de Janeiro', 4),
#  (395936422, 'Mobiliados', 'Rio de Janeiro', 4),
#  (23342524, 'Adriana', 'Rio de Janeiro', 4),
#  (72311432, 'Juliane', 'Rio de Janeiro', 4),
#  (163586041, 'Teresa', 'Rio de Janeiro', 4),
#  (491454926, 'Marcia', 'Rio de Janeiro', 4),
#  (7195997, 'Ana Lucia', 'Rio de Janeiro', 4),
#  (45269832, 'Nelia', 'Rio de Janeiro', 4),
#  (23265493, 'Vinicius', 'Rio de Janeiro', 4),
#  (9123104, 'Jose Antonio', 'Rio de Janeiro', 4),
#  (276875330, 'Gonzalo', 'Rio de Janeiro', 4),
#  (621406, 'Alexandre', 'Rio de Janeiro', 4),
#  (1142424, 'Taciana', 'Rio de Janeiro', 4),
#  (325866440, 'Enrique Y Fernanda', 'Rio de Janeiro', 4),
#  (509907088, 'Júlio', 'Rio de Janeiro', 4),
#  (18136498, 'Cassia', 'Rio de Janeiro', 4),
#  (433730519, 'Monica', 'Rio de Janeiro', 4),
#  (378156518, 'Mellany', 'Rio de Janeiro', 4),
#  (156839979, 'Diogo', 'Rio de Janeiro', 4),
#  (4955510, 'Figueiredo', 'Rio de Janeiro', 4),
#  (79878449, 'João Victor', 'Rio de Janeiro', 4),
#  (199325340, 'Casal Carioca Aluguel Temporada', 'Rio de Janeiro', 4),
#  (235496, 'Paola', 'Rio de Janeiro', 4),
#  (508835814, 'Rio To Stay', 'Rio de Janeiro', 4),
#  (241334, 'Andrea', 'Rio de Janeiro', 4),
#  (21416036, 'Ceci', 'Rio de Janeiro', 4),
#  (537934961, 'Enrico', 'Rio de Janeiro', 4),
#  (3701369, 'Eduardo', 'Rio de Janeiro', 4),
#  (482321954, 'Marcio', 'Rio de Janeiro', 4),
#  (499187589, 'Yann', 'Rio de Janeiro', 4),
#  (46809360, 'Vilma', 'Rio de Janeiro', 4),
#  (45156129, 'Jaden Matt', 'Rio de Janeiro', 4),
#  (702105, 'Sami', 'Rio de Janeiro', 4),
#  (26161863, 'Costa', 'Rio de Janeiro', 4),
#  (110142166, 'Lucinda', 'Rio de Janeiro', 4),
#  (491328775, 'Daniela', 'Rio de Janeiro', 4),
#  (61571618, 'Cesar', 'Rio de Janeiro', 4),
#  (374880383, 'Bossa Stay', 'Rio de Janeiro', 4),
#  (49194316, 'Cristian', 'Rio de Janeiro', 4),
#  (39901112, 'Ana Paula', 'Rio de Janeiro', 4),
#  (394983020, 'Roberta', 'Rio de Janeiro', 4),
#  (64230796, 'Larissa', 'Rio de Janeiro', 4),
#  (50477250, 'Veronica', 'Rio de Janeiro', 4),
#  (275440667, 'Gustavo', 'Rio de Janeiro', 4),
#  (105226518, 'Rio World Luxury', 'Rio de Janeiro', 4),
#  (46857325, 'Luiz Fernando', 'Rio de Janeiro', 4),
#  (53613804, 'Carmilton', 'Rio de Janeiro', 4),
#  (505400731, 'Daniel', 'Rio de Janeiro', 4),
#  (4501614, 'Patricia', 'Rio de Janeiro', 4),
#  (27462821, 'Lili', 'Rio de Janeiro', 4),
#  (210818814, 'Claudia', 'Rio de Janeiro', 4),
#  (75523708, 'Alessandro', 'Rio de Janeiro', 4),
#  (490731280, 'Gabriel', 'Rio de Janeiro', 4),
#  (104569146, 'Caio', 'Rio de Janeiro', 4),
#  (506608230, 'Sandra', 'Rio de Janeiro', 4),
#  (36518818, 'Emaise', 'Rio de Janeiro', 4),
#  (2948186, 'Rodrigo', 'Rio de Janeiro', 4),
#  (370073187, 'Jeferson', 'Rio de Janeiro', 4),
#  (8462462, 'Isabel', 'Rio de Janeiro', 4),
#  (141021345, 'Pedro', 'Rio de Janeiro', 4),
#  (500206265, 'Diego', 'Rio de Janeiro', 4),
#  (59089584, 'Luiz', 'Rio de Janeiro', 4),
#  (84909629, 'Juan', 'Rio de Janeiro', 4),
#  (50442621, 'Flávia', 'Rio de Janeiro', 4),
#  (490429714, 'Maria Isaura', 'Rio de Janeiro', 4),
#  (235468558, 'Jorge', 'Rio de Janeiro', 4),
#  (249164320, 'Carlos Arthur', 'Rio de Janeiro', 4),
#  (1542959, 'Rosa Maria', 'Rio de Janeiro', 4),
#  (312526846, 'Rodrigo', 'Rio de Janeiro', 4),
#  (374670667, 'Bheatriz', 'Rio de Janeiro', 4),
#  (284831228, 'Ana Paula', 'Rio de Janeiro', 4),
#  (23847033, 'Gustavo', 'Rio de Janeiro', 4),
#  (250158399, 'Cadu', 'Rio de Janeiro', 4),
#  (529089025, 'Jeremias', 'Rio de Janeiro', 4),
#  (82491056, 'Raphael', 'Rio de Janeiro', 4),
#  (322277570, 'Teresa', 'Rio de Janeiro', 4),
#  (1443646, 'Mônica', 'Rio de Janeiro', 4),
#  (246263247, 'Ethyenne', 'Rio de Janeiro', 4),
#  (435908522, 'Jakeline', 'Rio de Janeiro', 4),
#  (95906598, 'Décio Lacerda', 'Rio de Janeiro', 4),
#  (433611205, 'Joao', 'Rio de Janeiro', 4),
#  (4330477, 'Leonor Maria', 'Rio de Janeiro', 4),
#  (13903917, 'George', 'Rio de Janeiro', 4),
#  (298422241, 'Adriana', 'Rio de Janeiro', 4),
#  (295247469, 'Estanislava', 'Rio de Janeiro', 4),
#  (86777769, 'Alciete', 'Rio de Janeiro', 4),
#  (537990241, 'Emyli', 'Rio de Janeiro', 4),
#  (2870922, 'Carioca Da Urca', 'Rio de Janeiro', 4),
#  (177131210, 'Marcia Verginia', 'Rio de Janeiro', 4),
#  (491946086, 'Matheus', 'Rio de Janeiro', 4),
#  (193270591, 'Caroline', 'Rio de Janeiro', 4),
#  (245072737, 'Pedro', 'Rio de Janeiro', 4),
#  (15940255, 'Pedrita', 'Rio de Janeiro', 4),
#  (248648532, 'La Carioquice', 'Rio de Janeiro', 4),
#  (388598443, 'Sidney', 'Rio de Janeiro', 4),
#  (31314543, 'Tatiane', 'Rio de Janeiro', 4),
#  (128439524, 'Thamyres', 'Rio de Janeiro', 4),
#  (48898255, 'Camila', 'Rio de Janeiro', 4),
#  (51321275, 'Gustavo E Gabriela', 'Rio de Janeiro', 4),
#  (157701889, 'Caroline', 'Rio de Janeiro', 4),
#  (471638829, 'Jo', 'Rio de Janeiro', 4),
#  (14547679, 'Cris', 'Rio de Janeiro', 4),
#  (8527154, 'Solène', 'Rio de Janeiro', 4),
#  (227246641, 'Marissol', 'Rio de Janeiro', 4),
#  (2989144, 'Rafael', 'Rio de Janeiro', 4),
#  (106272295, 'André', 'Rio de Janeiro', 4),
#  (500892, 'Rafael', 'Rio de Janeiro', 4),
#  (125989559, 'Bruno', 'Rio de Janeiro', 4),
#  (325926574, 'Jean Pierre', 'Rio de Janeiro', 4),
#  (206684373, 'Samanta', 'Rio de Janeiro', 4),
#  (404178785, 'Alexandre', 'Rio de Janeiro', 4),
#  (266121934, 'Beatriz', 'Rio de Janeiro', 4),
#  (363276049, 'Tainá', 'Rio de Janeiro', 4),
#  (5866883, 'Aline', 'Rio de Janeiro', 4),
#  (491213647, 'Chrstina', 'Rio de Janeiro', 4),
#  (43594754, 'AnaCecilia', 'Rio de Janeiro', 4),
#  (454890496, 'Celeste', 'Rio de Janeiro', 4),
#  (21648920, 'Meu Anfitrião', 'Rio de Janeiro', 4),
#  (49860452, 'Claudia', 'Rio de Janeiro', 4),
#  (56572109, 'Doris', 'Rio de Janeiro', 4),
#  (2740249, 'Vincenzo', 'Rio de Janeiro', 4),
#  (445732926, 'Rioparadis', 'Rio de Janeiro', 4),
#  (225894302, 'La Casa Del Marco', 'Rio de Janeiro', 4),
#  (195684172, 'Sergio', 'Rio de Janeiro', 4),
#  (8317871, 'Grace', 'Rio de Janeiro', 4),
#  (451977285, 'Flávio', 'Rio de Janeiro', 4),
#  (14001603, 'Pedro Felipe', 'Rio de Janeiro', 4),
#  (72865722, 'Josy', 'Rio de Janeiro', 4),
#  (476162, 'Simone', 'Rio de Janeiro', 4),
#  (10649149, 'Edna', 'Rio de Janeiro', 4),
#  (258999505, 'Aldo', 'Rio de Janeiro', 4),
#  (212665255, "Sam'S Home", 'Rio de Janeiro', 4),
#  (1500231, 'Sarah', 'Rio de Janeiro', 4),
#  (466760781, 'AcuaRIO', 'Rio de Janeiro', 4),
#  (129454806, 'Johan & Barbara', 'Rio de Janeiro', 4),
#  (203061014, 'Felipe', 'Rio de Janeiro', 4),
#  (15226239, 'Lis', 'Rio de Janeiro', 4),
#  (85803917, 'Lua', 'Rio de Janeiro', 4),
#  (1603206, 'Bob', 'Rio de Janeiro', 4),
#  (8801218, 'Maria', 'Rio de Janeiro', 4),
#  (54538377, 'Igor', 'Rio de Janeiro', 4),
#  (251967883, 'Beatriz', 'Rio de Janeiro', 4),
#  (20906568, 'Roberta', 'Rio de Janeiro', 4),
#  (174004959, 'Jorge', 'Rio de Janeiro', 4),
#  (9459332, 'David', 'Rio de Janeiro', 4),
#  (69579533, 'Ana', 'Rio de Janeiro', 4),
#  (301071932, 'Mario', 'Rio de Janeiro', 4),
#  (12644787, 'Monica', 'Rio de Janeiro', 4),
#  (240682893, 'Luciano', 'Rio de Janeiro', 4),
#  (222701752, 'Sandro', 'Rio de Janeiro', 4),
#  (373346858, 'Cláudia Regina', 'Rio de Janeiro', 4),
#  (12963918, 'Laura', 'Rio de Janeiro', 4),
#  (2163079, 'Stanislas', 'Rio de Janeiro', 4),
#  (475701051, 'Daiana', 'Rio de Janeiro', 4),
#  (5507764, 'Caê', 'Rio de Janeiro', 4),
#  (3676628, 'Diego', 'Rio de Janeiro', 4),
#  (57358522, 'Pedro', 'Rio de Janeiro', 4),
#  (225698910, 'Monika', 'Rio de Janeiro', 4),
#  (4428126, 'Cesar', 'Rio de Janeiro', 4),
#  (318042617, 'Roberto', 'Rio de Janeiro', 4),
#  (89886135, 'Genivaldo', 'Rio de Janeiro', 4),
#  (325635866, 'Simone', 'Rio de Janeiro', 4),
#  (450206297, 'Preguiça Da Boa', 'Rio de Janeiro', 4),
#  (24425300, 'Bianca', 'Rio de Janeiro', 4),
#  (397908675, 'Wandyla', 'Rio de Janeiro', 4),
#  (36485470, 'Roberto', 'Rio de Janeiro', 4),
#  (15742382, 'Ester', 'Rio de Janeiro', 4),
#  (50596951, 'Miguel', 'Rio de Janeiro', 4),
#  (6504705, 'Philippe', 'Rio de Janeiro', 4),
#  (266300729, 'Sirlady', 'Rio de Janeiro', 4),
#  (418734004, 'Nubia', 'Rio de Janeiro', 4),
#  (192170777, 'Catia', 'Rio de Janeiro', 4),
#  (79571715, 'Ivone', 'Rio de Janeiro', 4),
#  (472982931, 'Anthony', 'Rio de Janeiro', 4),
#  (224118316, 'Ana Paula', 'Rio de Janeiro', 4),
#  (106248934, 'José Manoel', 'Rio de Janeiro', 4),
#  (81153486, 'Eudes', 'Rio de Janeiro', 4),
#  (411895655, 'Caroline', 'Rio de Janeiro', 4),
#  (132388145, 'Ivana', 'Rio de Janeiro', 4),
#  (376725829, 'Claudine', 'Rio de Janeiro', 4),
#  (475372439, 'Maria', 'Rio de Janeiro', 4),
#  (15991909, 'Yona', 'Rio de Janeiro', 4),
#  (304153498, 'Aldaci De Freitas Damasceno', 'Rio de Janeiro', 4),
#  (30729912, 'Marcelo', 'Rio de Janeiro', 4),
#  (64757298, 'Rosário', 'Rio de Janeiro', 4),
#  (9240616, 'Nils', 'Rio de Janeiro', 4),
#  (55123769, 'Mariana', 'Rio de Janeiro', 4),
#  (533666, 'Sandra Valéria', 'Rio de Janeiro', 4),
#  (384046862, 'Eduarda', 'Rio de Janeiro', 4),
#  (150289633, 'Braian', 'Rio de Janeiro', 4),
#  (227328625, 'Alexandre', 'Rio de Janeiro', 4),
#  (134405287, 'Francisco', 'Rio de Janeiro', 4),
#  (151508372, 'Luisa', 'Rio de Janeiro', 4),
#  (125121750, 'Igor', 'Rio de Janeiro', 4),
#  (10491355, 'Hanna', 'Rio de Janeiro', 4),
#  (15738587, 'Claudia', 'Rio de Janeiro', 4),
#  (37837293, 'Tatiana', 'Rio de Janeiro', 4),
#  (14848679, 'Jô', 'Rio de Janeiro', 4),
#  (4218951, 'Maria', 'Rio de Janeiro', 4),
#  (72296387, 'Wilson', 'Rio de Janeiro', 4),
#  (548556494, 'Fernanda', 'Rio de Janeiro', 4),
#  (78463246, 'Thiago', 'Rio de Janeiro', 4),
#  (366265885, 'Carla', 'Rio de Janeiro', 4),
#  (1450861, 'Leila', 'Rio de Janeiro', 4),
#  (426749155, 'Gabriela', 'Rio de Janeiro', 4),
#  (16023706, 'Secreto', 'Rio de Janeiro', 4),
#  (2034245, 'Georgette', 'Rio de Janeiro', 4),
#  (60356266, 'Marcella', 'Rio de Janeiro', 4),
#  (125736861, 'Marcelo', 'Rio de Janeiro', 4),
#  (521593918, 'Oka', 'Rio de Janeiro', 4),
#  (441941839, 'Rosana', 'Rio de Janeiro', 4),
#  (460275003, 'Enzo', 'Rio de Janeiro', 4),
#  (142781510, 'Marta', 'Rio de Janeiro', 4),
#  (444172537, 'Marie', 'Rio de Janeiro', 4),
#  (148198271, 'Verônica', 'Rio de Janeiro', 4),
#  (7834157, 'Andrea', 'Rio de Janeiro', 4),
#  (73791443, 'Nara', 'Rio de Janeiro', 4),
#  (384444289, 'Daniel', 'Rio de Janeiro', 4),
#  (9819895, 'João Pedro', 'Rio de Janeiro', 4),
#  (376765302, 'Felipe', 'Rio de Janeiro', 4),
#  (213031642, 'Lília', 'Rio de Janeiro', 4),
#  (63899823, 'Go To Rio Rentals', 'Rio de Janeiro', 4),
#  (532098610, 'Marcelo', 'Rio de Janeiro', 4),
#  (32266792, 'Sandro', 'Rio de Janeiro', 4),
#  (449677, 'Renato / Louri', 'Rio de Janeiro', 4),
#  (38364611, 'Maria', 'Rio de Janeiro', 4),
#  (378111934, 'Luiz', 'Rio de Janeiro', 4),
#  (136462716, 'Oabitat', 'Rio de Janeiro', 4),
#  (75086118, 'Solange', 'Rio de Janeiro', 4),
#  (4506032, 'Maria', 'Rio de Janeiro', 4),
#  (83731252, 'Marcellus Passamani', 'Rio de Janeiro', 4),
#  (25002900, 'Elizabeth', 'Rio de Janeiro', 4),
#  (98040033, 'Patricia', 'Rio de Janeiro', 4),
#  (427360088, 'Miriam', 'Rio de Janeiro', 4),
#  (203289711, 'Priscilla', 'Rio de Janeiro', 4),
#  (235390957, 'Bruna', 'Rio de Janeiro', 4),
#  (197956877, 'Paula', 'Rio de Janeiro', 4),
#  (229434751, 'Gabriella', 'Rio de Janeiro', 4),
#  (14983440, 'PabloKaschner', 'Rio de Janeiro', 4),
#  (31478078, 'Victor', 'Rio de Janeiro', 4),
#  (1125885, 'Adriana', 'Rio de Janeiro', 4),
#  (12023444, 'Rachel', 'Rio de Janeiro', 4),
#  (263829913, 'Andre', 'Rio de Janeiro', 4),
#  (223241515, 'Jahys', 'Rio de Janeiro', 4),
#  (13603514, 'Nadja', 'Rio de Janeiro', 4),
#  (5052093, 'Pyari', 'Rio de Janeiro', 4),
#  (160313981, 'Drika', 'Rio de Janeiro', 4),
#  (225323653, 'Livia', 'Rio de Janeiro', 4),
#  (2694627, 'Ricardo', 'Rio de Janeiro', 4),
#  (366681778, 'Roberta', 'Rio de Janeiro', 4),
#  (1809627, 'Angelica And Bob', 'Rio de Janeiro', 4),
#  (27752766, 'Carlos', 'Rio de Janeiro', 4),
#  (444164486, 'Daniella', 'Rio de Janeiro', 4),
#  (164177980, 'Flávia', 'Rio de Janeiro', 4),
#  (261848845, 'Arosa', 'Rio de Janeiro', 4),
#  (115783339, 'Helena', 'Rio de Janeiro', 4),
#  (14810503, 'Marcelle', 'Rio de Janeiro', 4),
#  (389379436, 'Beatriz', 'Rio de Janeiro', 4),
#  (50435064, 'Paula', 'Rio de Janeiro', 4),
#  (4536917, 'Rodrigo', 'Rio de Janeiro', 4),
#  (521613, 'Cyro', 'Rio de Janeiro', 4),
#  (61433326, 'Account Manager', 'Rio de Janeiro', 4),
#  (35820493, 'Vitinho', 'Rio de Janeiro', 4),
#  (137360954, 'Gustavo', 'Rio de Janeiro', 4),
#  (510646750, 'Carlos', 'Rio de Janeiro', 4),
#  (2521176, 'Casa', 'Rio de Janeiro', 4),
#  (61163071, 'Diogo', 'Rio de Janeiro', 4),
#  (274871877, 'Luiz Fernando', 'Rio de Janeiro', 4),
#  (214026083, 'Danillo', 'Rio de Janeiro', 4),
#  (29349957, 'Lisiane', 'Rio de Janeiro', 4),
#  (49661699, 'Mari', 'Rio de Janeiro', 4),
#  (1500426, 'Flat', 'Rio de Janeiro', 4),
#  (7089390, 'Marcela', 'Rio de Janeiro', 4),
#  (11933736, 'Luiz', 'Rio de Janeiro', 4),
#  (1846563, 'Edgar', 'Rio de Janeiro', 4),
#  (230557551, 'Cristiane', 'Rio de Janeiro', 4),
#  (316737705, 'Yasmin', 'Rio de Janeiro', 4),
#  (24401743, 'Andrew', 'Rio de Janeiro', 4),
#  (11762800, 'Maurizio', 'Rio de Janeiro', 4),
#  (10122044, 'Eduardo', 'Rio de Janeiro', 4),
#  (15025261, 'Eliana', 'Rio de Janeiro', 4),
#  (285077915, 'Gisela Maria', 'Rio de Janeiro', 4),
#  (56058824, 'Tatiana', 'Rio de Janeiro', 4),
#  (238713778, 'Maria', 'Rio de Janeiro', 4),
#  (141142347, 'Mary', 'Rio de Janeiro', 4),
#  (145715166, 'Ivan', 'Rio de Janeiro', 4),
#  (216491558, 'Cátia', 'Rio de Janeiro', 4),
#  (480310607, 'Evelyn', 'Rio de Janeiro', 4),
#  (551115761, 'Maria Do Socorro', 'Rio de Janeiro', 4),
#  (160440618, 'Elaine', 'Rio de Janeiro', 4),
#  (53714117, 'Rayan', 'Rio de Janeiro', 4),
#  (35297336, 'Natalia', 'Rio de Janeiro', 4),
#  (7763745, 'Deborah', 'Rio de Janeiro', 4),
#  (23833600, 'Lucas', 'Rio de Janeiro', 4),
#  (419894206, 'Rede Reserva', 'Rio de Janeiro', 4),
#  (134569719, 'Luiza', 'Rio de Janeiro', 4),
#  (491710888, 'Josué Rodrigues Do Carmo', 'Rio de Janeiro', 4),
#  (29678743, 'Baldô', 'Rio de Janeiro', 4),
#  (235288256, 'Tyago', 'Rio de Janeiro', 4),
#  (14583404, 'Soraya', 'Rio de Janeiro', 4),
#  (12508023, 'Marcelle', 'Rio de Janeiro', 4),
#  (4708373, 'Andres', 'Rio de Janeiro', 4),
#  (4613553, 'Frank', 'Rio de Janeiro', 4),
#  (543593557, 'Aline', 'Rio de Janeiro', 4),
#  (445989773, 'Maria Da Penha', 'Rio de Janeiro', 4),
#  (84682646, 'Ligia', 'Rio de Janeiro', 4),
#  (64517824, 'José Franklin', 'Rio de Janeiro', 4),
#  (78960552, 'Cristina', 'Rio de Janeiro', 4),
#  (187621192, 'Suzana', 'Rio de Janeiro', 4),
#  (474221, 'June', 'Rio de Janeiro', 4),
#  (102407623, 'Gabriel', 'Rio de Janeiro', 4),
#  (235977095, 'Luiz', 'Rio de Janeiro', 4),
#  (61889802, 'Breno', 'Rio de Janeiro', 4),
#  (4780133, 'Lorenzo', 'Rio de Janeiro', 4),
#  (4347269, 'Patrick', 'Rio de Janeiro', 4),
#  (35591003, 'Alexandre', 'Rio de Janeiro', 4),
#  (662146, 'Deborah', 'Rio de Janeiro', 4),
#  (88757714, 'Ana Claudia', 'Rio de Janeiro', 4),
#  (503285061, 'Pedro', 'Rio de Janeiro', 4),
#  (175665960, 'Elis', 'Rio de Janeiro', 4),
#  (224784651, 'Patrícia', 'Rio de Janeiro', 4),
#  (333857358, 'Rafaele', 'Rio de Janeiro', 4),
#  (20362236, 'Júlio Cesar', 'Rio de Janeiro', 4),
#  (392769753, 'Amanda', 'Rio de Janeiro', 4),
#  (24415930, 'Cristina', 'Rio de Janeiro', 4),
#  (105571030, 'Miriam', 'Rio de Janeiro', 4),
#  (477118176, 'Adylis', 'Rio de Janeiro', 4),
#  (208190186, 'Thiago', 'Rio de Janeiro', 4),
#  (370324244, 'Ana Paula', 'Rio de Janeiro', 4),
#  (46082356, 'Patrícia', 'Rio de Janeiro', 4),
#  (171256195, 'Rio Rentals 021', 'Rio de Janeiro', 4),
#  (8479954, 'Naira Beatriz', 'Rio de Janeiro', 4),
#  (74978304, 'Maidy', 'Rio de Janeiro', 4),
#  (25846656, 'Daniel', 'Rio de Janeiro', 3),
#  (344229824, 'Nianta Fernanda', 'Rio de Janeiro', 3),
#  (103691209, 'José', 'Rio de Janeiro', 3),
#  (3798805, 'Ana', 'Rio de Janeiro', 3),
#  (14805617, 'Alessandra', 'Rio de Janeiro', 3),
#  (2942002, 'Paulo Fernando', 'Rio de Janeiro', 3),
#  (109980555, 'Josiane', 'Rio de Janeiro', 3),
#  (79065425, 'Ugo', 'Rio de Janeiro', 3),
#  (172059617, 'Andrea', 'Rio de Janeiro', 3),
#  (10893041, 'Vitoria', 'Rio de Janeiro', 3),
#  (471532909, 'Mara', 'Rio de Janeiro', 3),
#  (537109, 'Amaury', 'Rio de Janeiro', 3),
#  (12596481, 'Selma', 'Rio de Janeiro', 3),
#  (22860550, 'Oliver', 'Rio de Janeiro', 3),
#  (54351415, 'Hannes', 'Rio de Janeiro', 3),
#  (372571071, 'Erick', 'Rio de Janeiro', 3),
#  (43714852, 'Raphael', 'Rio de Janeiro', 3),
#  (56451628, 'André & Fabiana', 'Rio de Janeiro', 3),
#  (35589433, 'Lenna', 'Rio de Janeiro', 3),
#  (172573150, 'Thais Schmitt', 'Rio de Janeiro', 3),
#  (10096448, 'Marlene E', 'Rio de Janeiro', 3),
#  (358108490, 'Maria', 'Rio de Janeiro', 3),
#  (8008479, 'Rosilea', 'Rio de Janeiro', 3),
#  (340982658, 'Simone', 'Rio de Janeiro', 3),
#  (170897840, 'Eliz', 'Rio de Janeiro', 3),
#  (4652415, 'Tania', 'Rio de Janeiro', 3),
#  (535366959, 'Neucely', 'Rio de Janeiro', 3),
#  (2444956, 'Jeanne', 'Rio de Janeiro', 3),
#  (20407614, 'Augusto', 'Rio de Janeiro', 3),
#  (550738493, 'Lourdes', 'Rio de Janeiro', 3),
#  (336208953, 'Alexandre', 'Rio de Janeiro', 3),
#  (44868085, 'Gabriela', 'Rio de Janeiro', 3),
#  (29962920, 'Alvaro', 'Rio de Janeiro', 3),
#  (26276186, 'Wanda', 'Rio de Janeiro', 3),
#  (3167047, 'Vergilio', 'Rio de Janeiro', 3),
#  (297916307, 'Frederico', 'Rio de Janeiro', 3),
#  (421014730, 'Jose', 'Rio de Janeiro', 3),
#  (17172474, 'Francilene Lopes', 'Rio de Janeiro', 3),
#  (322165947, 'Damasceno', 'Rio de Janeiro', 3),
#  (33380740, 'Andre', 'Rio de Janeiro', 3),
#  (184602206, 'Li', 'Rio de Janeiro', 3),
#  (14766704, 'Ligia', 'Rio de Janeiro', 3),
#  (33351403, 'Sabrina', 'Rio de Janeiro', 3),
#  (466355464, 'Guilherme', 'Rio de Janeiro', 3),
#  (162366245, 'Karol', 'Rio de Janeiro', 3),
#  (469973891, 'Monica', 'Rio de Janeiro', 3),
#  (24865795, 'Cecília', 'Rio de Janeiro', 3),
#  (493954441, 'Ivone Lopes', 'Rio de Janeiro', 3),
#  (14163574, 'Tatiana', 'Rio de Janeiro', 3),
#  (83920896, 'Ingrid', 'Rio de Janeiro', 3),
#  (240470377, 'Marcia', 'Rio de Janeiro', 3),
#  (177917831, 'Catia', 'Rio de Janeiro', 3),
#  (170916608, 'Gabriel', 'Rio de Janeiro', 3),
#  ...]

# %% [markdown]
# # Trabalho 2 de Banco de Dados - SCC0240

# %% [markdown]
# ## Imports e Testes
# Checando se tudo está funcionando

# %%
from ipywidgets import interact 
import ipywidgets as widgets
from sqlalchemy import create_engine

# %%
# %load_ext sql

engine = create_engine('postgresql://postgres:postgres@localhost/trabbd')
# %sql postgresql://postgres:postgres@localhost/trabbd
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Change displaylimit

# %%
# %config SqlMagic.displaylimit = 20
# %config SqlMagic.style = 'MARKDOWN'

# %%
# %%sql
# SELECT Current_database();
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 1 rows affected.
# [('trabbd',)]

# %% [markdown]
# ## 3. Criação e carga de tabelas

# %% [markdown]
# ### 1. Criação de tabelas do Airbnb

# %%
# %sql --file sql/3CriacaoAirbnb.sql
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# (psycopg2.ProgrammingError) can't execute an empty query
# [SQL: -- -- Load data into Listings
# -- COPY Listings(id, name, neighbourhood, room_type, price, minimum_nights, maximum_nights, number_of_reviews, last_review, calculated_host_listings_count, availability_365)
# -- FROM '/tmp/listings.csv' DELIMITER ',' CSV HEADER;
# -- -- Load data into Calendar
# -- COPY Calendar(listing_id, date, available, price)
# -- FROM '/tmp/calendar.csv' DELIMITER ',' CSV HEADER;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ### 2. Carga de tabelas do Airbnb

# %%
! psql -U postgres -c "\copy Reviews from /tmp/reviews.csv delimiter ',' CSV HEADER;"
! psql -U postgres -c "\copy Listings from /tmp/listings.csv delimiter ',' CSV HEADER;"
! psql -U postgres -c "\copy Calendar from /tmp/calendar.csv delimiter ',' CSV HEADER;"

# %% [markdown]
# ### 3. Criação e carga de Tabelas mapeadas pelo MRel

# %%
# %%capture
# %sql --file sql/2CriacaoTabelasMRel.sql

# %sql --file sql/3CargaTabelasMRel.sql
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
#  * postgresql://postgres:***@localhost/trabbd
# 703796 rows affected.
# 6667756 rows affected.
# 156 rows affected.
# 36008 rows affected.
# 36008 rows affected.
# []

# %%
# %sql SELECT * FROM pg_catalog.pg_tables;
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 85 rows affected.
# [('pg_catalog', 'pg_statistic', 'postgres', None, True, False, False, False),
#  ('pg_catalog', 'pg_type', 'postgres', None, True, False, False, False),
#  ('public', 'localizacoes', 'postgres', None, True, False, False, False),
#  ('public', 'usuarios', 'postgres', None, False, False, False, False),
#  ('public', 'mensagens', 'postgres', None, False, False, False, False),
#  ('public', 'locacao', 'postgres', None, False, False, False, False),
#  ('public', 'pontosinteresse', 'postgres', None, False, False, False, False),
#  ('public', 'fotos', 'postgres', None, False, False, False, False),
#  ('public', 'quartos', 'postgres', None, False, False, False, False),
#  ('public', 'comodidades', 'postgres', None, False, False, False, False),
#  ('public', 'contas', 'postgres', None, False, False, False, False),
#  ('public', 'datasdisponiveis', 'postgres', None, False, False, False, False),
# ...

# %% [markdown]
# ## 4. Consultas

# %% [markdown]
# ### Exercício 6

# %%
# %sql select * from propriedades
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 36008 rows affected.
# [(17878, 'Condo in Rio de Janeiro · ★4.70 · 2 bedrooms · 2 beds · 1 bath', None, 41, 68997, None, None, 1357.0, None, 5, None, None, None, None, None),
#  (216461, 'Rental unit in Rio de Janeiro · 1 bedroom · 1 bed · 1 bath', None, 102, 1154263, None, None, 734.0, None, 1, None, None, None, None, None),
#  (326205, 'Condo in Rio de Janeiro · ★4.57 · 1 bedroom · 1 bed · 1 bath', None, 41, 1603206, None, None, 366.0, None, 3, None, None, None, None, None),
#  (25026, 'Rental unit in Rio de Janeiro · ★4.72 · 1 bedroom · 1 bed · 1 bath', None, 41, 102840, None, None, 865.0, None, 2, None, None, None, None, None),
#  (326575, 'Rental unit in Rio de Janeiro · ★4.81 · 2 bedrooms · 3 beds · 2 baths', None, 41, 1668565, None, None, 368.0, None, 4, None, None, None, None, None),
# ...

# %%
# %sql --file sql/ex6.sql
# Out:
#  * postgresql://postgres:***@localhost/trabbd
# 156 rows affected.
# [(1, 'Quintino Bocaiúva', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (2, 'Acari', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (3, 'Lins de Vasconcelos', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (4, 'Vaz Lobo', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (5, 'Turiaçú', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (6, 'Glória', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (7, 'Osvaldo Cruz', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (8, 'Grajaú', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (9, 'Coelho Neto', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (10, 'Mangueira', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (11, 'Santíssimo', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (12, 'Tomás Coelho', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (13, 'Engenho Novo', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (14, 'Estácio', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (15, 'Pechincha', 'Brasil', 'RJ', 'Rio de Janeiro'),
#  (16, 'Engenho de Dentro', 'Brasil', 'RJ', 'Rio de Janeiro'),
# ...
